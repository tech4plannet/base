# %% [markdown]
# ![image.png](attachment:image-2.png)

# %% [markdown]
# # A Business Case for Predictive Pipeline Maintenance
#
# ## IE Sustainability Datathon 2023
#
# ### Tech4Planet: https://github.com/orgs/tech4plannet/

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# # Structure of these series of Jupyter Notebooks
# ### ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# ### 1. EDA
#
# ### 2. Inspection Strategy
#
# ### 3. Data Wrangling and Feature Engineering
#
# ### 4. Preparing Data Submission Sample
#
# ### 5. Random Forest
#
# ### 6. PCA, XGBoost and other approaches
#
# ### ==========================================================================
# ## You are in Notebook 3: Data Wrangling and Feature Engineering (3/6)
# ### ==========================================================================

# %% [markdown]
# # <font color=green> Table of contents </font>
#
# * [__1. Libraries Used__](#1)
# * [__2. Loading Datasets__](#2)
# * [__3. Data Wrangling__](#3)
# * [__4. Feature Engineering__](#4)
# * [__5. Adding a new dataset__](#5)
# * [__6. Outliers__](#6)
# * [__7. Dropping__](#7)
# * [__8. Exporting resulting dataframe for next notebook__](#8)
# * [__9. Pandas Profiling Report__](#9)

# %% [markdown]
# <a id='1'></a>
# # <font color=green> 1. Libaries used </font>

# %% [markdown]
# ## <font color=green> 1.1 Requirements </font>

# %%
#perform al #pip installs in one go comment out if already installed
#pip install pandas
#pip install numpy
#pip install matplotlib
#pip install seaborn
#pip install sklearn
#pip install scipy
#pip install statsmodels
#pip install plotly
#pip install cufflinks
#pip install squarify
#pip install yellowbrick
#pip install lazypredict
#pip install pandas_profiling

# %% [markdown]
# ## <font color=green> 1.2 Imports </font>

# %%
import pandas as pd
import numpy as np
import seaborn as sns  
import matplotlib.pyplot as plt
import plotly.io as pio
import os
import matplotlib
import warnings

#to enable the inline plotting
# %matplotlib inline 

import warnings
warnings.filterwarnings('ignore')

sns.set_style("darkgrid")

# %%
from sklearn.preprocessing import StandardScaler
from scipy.stats import normaltest
from sklearn.preprocessing import PolynomialFeatures
from pandas_profiling import ProfileReport
from yellowbrick.classifier import ROCAUC
from yellowbrick.classifier import ClassPredictionError
from yellowbrick.style.palettes import PALETTES, SEQUENCES, color_palette
import plotly.express as px
import lazypredict
from lazypredict.Supervised import LazyClassifier

warnings.simplefilter(action='ignore', category=FutureWarning)

# %% [markdown]
# ## <font color=green> 1.3 Functions </font>

# %%
# Function for EDA. Using the display() function to have  well-formatted tables. We are mainly using pandas to explore the datasets

def dataset_description(df_target):

    print('This is the Dataset shape: %s\n' % (df_target.shape, ))
    print('Dataset columns: %s\n' % df_target.columns)

    print('\nColumns description:\n')
    display(df_target.info())
    display(df_target.describe())  # describe the dataset

    print('\nNull values:\n')
    display(df_target.isnull().sum())  # Identify null values

#function performing a quick check on df_inspection to have best of pandas functions separated by a line
def quick_check(dataframe):
    print('First 5 rows %s\n')
    print(dataframe.head(2))
    print("=====================================")
    print('Dataframe shape %s\n')
    print(dataframe.shape)
    print("=====================================")
    print('Dataframe describe categorical %s\n')
    print(dataframe.describe(include=['O']))
    print("=====================================")
    print('Dataframe null values %s\n')
    print(dataframe.isnull().sum())
    print("=====================================")
    print('Dataframe value counts %s\n')
    print(dataframe.value_counts())
    print("=====================================")

#stats function
def stats(dataframe):
    print('Dataframe correlation %s\n')
    print(dataframe.corr())
    print("=====================================")
    print('Dataframe covariance %s\n')
    print(dataframe.cov())
    print("=====================================")
    print('Dataframe skew %s\n')
    print(dataframe.skew())
    print("=====================================")
    print('Dataframe kurtosis %s\n')
    print(dataframe.kurt())
    print("=====================================")

#create a function to normalize characters from a dataset's column in Spanish
def normalize_characters(df, column):
    df[column] = df[column].str.normalize('NFKD').str.encode('ascii', errors='ignore').str.decode('utf-8')
    df[column] = df[column].str.lower()
    df[column] = df[column].str.replace('á', 'a')
    df[column] = df[column].str.replace('é', 'e')
    df[column] = df[column].str.replace('í', 'i')
    df[column] = df[column].str.replace('ó', 'o')
    df[column] = df[column].str.replace('ú', 'u')
    df[column] = df[column].str.replace('ñ', 'n')
    df[column] = df[column].str.replace('ü', 'u')
    df[column] = df[column].str.replace('ç', 'c')
    df[column] = df[column].str.replace('(', '')
    df[column] = df[column].str.replace(')', '')
    df[column] = df[column].str.replace('\'', '')
    df[column] = df[column].str.replace('´', '')
    df[column] = df[column].str.replace('`', '')
    df[column] = df[column].str.replace('’', '')
    return df.head(2)

#create function to change detypes in64 to int32 in a df
def change_dtypes(df):
    for col in df.columns:
        if df[col].dtype == 'int64':
            df[col] = df[col].astype('int32')
        elif df[col].dtype == 'float64':
            df[col] = df[col].astype('float32')
    return df

# %%
#show all print outputs when using a function
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

#display all columns
pd.set_option('display.max_columns', None)

# %% [markdown]
# <a id='2'></a>
# # <font color=green> 2. Loading Datasets</font>

# %%
#point to the folder where the data is stored for Pedro
os.chdir(r"C:\Users\pedro\datathon")

# Loading inspection data
df_inspection = pd.read_csv('inspections.csv')

# Loading network data
df_network = pd.read_csv('network.csv')

# %% [markdown]
# ## <font color=green> 2.1 First Look at data</font>

# %%
quick_check(df_inspection)
# Out:
# First 5 rows %s
#
#       PipeId MaintenanceId  InspectionYear InspectionDate  MonthsLastRev  \
# 0  189311802  ZRV-00001972            2010     2010-10-01             24
# 1  188889914  ZRV-00001406            2010     2010-10-01             22
#
#    Severity  Incidence
# 0         4          0
# 1         4          0
# =====================================
# Dataframe shape %s
#
# (6345344, 7)
# =====================================
# Dataframe describe categorical %s
#
#        MaintenanceId InspectionDate
# count        6345344        6345344
# unique          4179           3565
# top     ZRV-00002121     2014-05-05
# freq           21773           5832
# =====================================
# Dataframe null values %s
#
# PipeId            0
# MaintenanceId     0
# InspectionYear    0
# InspectionDate    0
# MonthsLastRev     0
# Severity          0
# Incidence         0
# dtype: int64
# =====================================
# Dataframe value counts %s
#
# PipeId     MaintenanceId  InspectionYear  InspectionDate  MonthsLastRev  Severity  Incidence
# 489616     ZRV-00003385   2013            2013-05-08      16             4         0            1
# 256852211  ZRV-00002129   2016            2016-10-10      24             4         0            1
# 256831542  ZRV-00004585   2018            2018-07-23      24             4         0            1
#                           2016            2016-07-14      24             4         0            1
#                           2014            2014-07-10      24             4         0            1
#                                                                                                ..
# 188595687  ZRV-00003626   2018            2018-02-15      24             4         0            1
#                           2016            2016-02-17      24             4         0            1
#                           2014            2014-02-12      24             4         0            1
#                           2012            2012-02-20      24             4         0            1
# 451995309  ZRV-00001573   2019            2019-10-26      24             4         0            1
# Length: 6345344, dtype: int64
# =====================================

# %% [markdown]
# - The function shows we have 6345344 rows for the inspections, among each 4179 appear to be unique and the most repeated one is ZRV-00002121 on 2014-05-05
#
# We perform some queries now

# %%
#searching for MaintenanceId ZRV-00002121 in df_inspection
df_inspection[df_inspection['MaintenanceId'] == 'ZRV-00002121']
# Out:
#             PipeId MaintenanceId  InspectionYear InspectionDate  \
# 622563   188821075  ZRV-00002121            2012     2011-12-28
# 622571   191340447  ZRV-00002121            2012     2011-12-28
# 622572   191340427  ZRV-00002121            2012     2011-12-28
# 622574   191340421  ZRV-00002121            2012     2011-12-28
# 622575   188802580  ZRV-00002121            2012     2011-12-28
# ...            ...           ...             ...            ...
# 5737006  450197378  ZRV-00002121            2020     2020-01-29
# 5737013  358229516  ZRV-00002121            2020     2020-01-29
# 5737179  351671916  ZRV-00002121            2020     2020-01-29
# 5737289  351671518  ZRV-00002121            2020     2020-01-29
# 5737290  191365725  ZRV-00002121            2020     2020-01-29
#
#          MonthsLastRev  Severity  Incidence
# 622563              24         4          0
# 622571              24         4          0
# 622572              24         4          0
# 622574              24         4          0
# 622575              24         4          0
# ...                ...       ...        ...
# 5737006             24         4          0
# 5737013             24         4          0
# 5737179             24         4          0
# 5737289             24         4          0
# 5737290             24         4          0
#
# [21773 rows x 7 columns]

# %%
df_inspection[df_inspection['MaintenanceId'] == 'ZRV-00002121'].shape
# Out:
# (21773, 7)

# %%
#plotting the distribution of MaintenanceId accross the years for ZRV-00002121 in df_inspection
df_inspection[df_inspection['MaintenanceId'] == 'ZRV-00002121'].groupby('InspectionYear')['MaintenanceId'].count().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='InspectionYear'>

# %%
#plotting the distribution of MaintenanceId accross the years
df_inspection.groupby('InspectionYear')['MaintenanceId'].count().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='InspectionYear'>

# %% [markdown]
# - Seems like not so many inspections were carried in 2010, though the number is small, we will not drop these values

# %%
stats(df_inspection)
# Out:
# Dataframe correlation %s
#
#                 PipeId  InspectionYear  MonthsLastRev  Severity  Incidence
# PipeId            1.00           -0.12           0.05      0.02      -0.02
# InspectionYear   -0.12            1.00           0.12      0.00      -0.00
# MonthsLastRev     0.05            0.12           1.00      0.01      -0.01
# Severity          0.02            0.00           0.01      1.00      -0.90
# Incidence        -0.02           -0.00          -0.01     -0.90       1.00
# =====================================
# Dataframe covariance %s
#
#                              PipeId  InspectionYear  MonthsLastRev  Severity  \
# PipeId         12943583115885750.00    -40999914.58    27545538.86 129283.54
# InspectionYear         -40999914.58            8.46           1.70      0.00
# MonthsLastRev           27545538.86            1.70          24.62      0.00
# Severity                  129283.54            0.00           0.00      0.00
# Incidence                -107454.24           -0.00          -0.00     -0.00
#
#                 Incidence
# PipeId         -107454.24
# InspectionYear      -0.00
# MonthsLastRev       -0.00
# Severity            -0.00
# Incidence            0.00
# =====================================
# Dataframe skew %s
#
# PipeId            -0.07
# InspectionYear    -0.10
# MonthsLastRev      3.68
# Severity         -31.01
# Incidence         22.62
# dtype: float64
# =====================================
# Dataframe kurtosis %s
#
# PipeId             -0.72
# InspectionYear     -1.18
# MonthsLastRev      41.37
# Severity         1131.62
# Incidence         509.71
# dtype: float64
# =====================================

# %% [markdown]
# -  A positive kurtosis in a dataset implies that the data is more heavily concentrated around the mean than a normal distribution. This means that there are more outliers in the dataset and that the tails of the distribution are longer and fatter than a normal distribution.
#
# - Months last revision is to be examined on this basis

# %%
#plot histogram with many bins of MonthsLastRev in  df_inspection
df_inspection['MonthsLastRev'].hist(bins=100)
# Out:
# <AxesSubplot:>

# %% [markdown]
# - The shape of the histogram reveals the most frequent inspections take place every 2 years or 24 months with some outliers hence affecting the normal distribution

# %%
quick_check(df_network)
# Out:
# First 5 rows %s
#
#    PipeId     Province                   Town  YearBuilt Material  \
# 0  489616  Ciudad Real  Torralba de Calatrava       2012       PE
# 1  489645  Ciudad Real  Torralba de Calatrava       2012       PE
#
#        GasType  Diameter  Length  Pressure  NumConnections  \
# 0  Gas natural     63.00    7.79      0.40               0
# 1  Gas natural     90.00    2.08      0.40               0
#
#    NumConnectionsUnder  BoolBridle
# 0                    0       False
# 1                    0       False
# =====================================
# Dataframe shape %s
#
# (1446539, 12)
# =====================================
# Dataframe describe categorical %s
#
#          Province     Town Material      GasType
# count     1446539  1446539  1446539      1446539
# unique         38     1972       11            2
# top     Barcelona   Madrid       PE  Gas natural
# freq       389307    76666  1242845      1388397
# =====================================
# Dataframe null values %s
#
# PipeId                 0
# Province               0
# Town                   0
# YearBuilt              0
# Material               0
# GasType                0
# Diameter               0
# Length                 0
# Pressure               0
# NumConnections         0
# NumConnectionsUnder    0
# BoolBridle             0
# dtype: int64
# =====================================
# Dataframe value counts %s
#
# PipeId     Province     Town                   YearBuilt  Material  GasType      Diameter  Length  Pressure  NumConnections  NumConnectionsUnder  BoolBridle
# 489616     Ciudad Real  Torralba de Calatrava  2012       PE        Gas natural  63.00     7.79    0.40      0               0                    False         1
# 229894572  León         Valencia de Don Juan   2004       PE        Gas natural  110.00    10.63   0.15      0               0                    False         1
# 229912516  León         Ponferrada             2004       PE        Gas natural  63.00     8.52    4.00      0               0                    False         1
# 229912137  León         Ponferrada             2004       PE        Gas natural  63.00     8.01    4.00      0               0                    False         1
# 229912078  León         Ponferrada             2004       PE        Gas natural  63.00     2.02    4.00      0               0                    False         1
#                                                                                                                                                                ..
# 133749590  Lugo         Lugo                   2003       PE        Gas natural  110.00    0.87    0.15      0               0                    False         1
# 133749584  Lugo         Lugo                   2003       PE        Gas natural  110.00    5.71    0.15      0               0                    False         1
# 133749577  Lugo         Lugo                   2003       PE        Gas natural  110.00    93.39   0.15      2               0                    False         1
# 133749571  Lugo         Lugo                   2003       PE        Gas natural  160.00    6.57    0.15      0               0                    False         1
# 451995309  Lleida       Almacelles             1998       PE        Gas natural  200.00    92.22   0.15      0               0                    False         1
# Length: 1446539, dtype: int64
# =====================================

# %% [markdown]
# - In the network file we find 1446539 rows corresponding to all pipes, this is the master file for pipes.
#
# - We find the most frequent Town is Madrid but the most frequent province is Barcelona.
#
# - There are a total of 1972 Spanish towns in this dataset and 38 provinces
# We are missing the Basque Country, Ceuta, Melilla, the Canary Islands and Balearic Islands.

# %%
#plot a bar plot with the number of pipes per Town focusing in Madrid and Barcelona  in df_network
df_network.groupby('Town')['PipeId'].count().sort_values(ascending=False).head(10).plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Town'>

# %%
#plot a pie chart with the number of pipes per Province in df_network 
df_network.groupby('Province')['PipeId'].count().sort_values(ascending=False).plot(kind='pie')
# Out:
# <AxesSubplot:ylabel='PipeId'>

# %%
stats(df_network)
# Out:
# Dataframe correlation %s
#
#                      PipeId  YearBuilt  Diameter  Length  Pressure  \
# PipeId                 1.00      -0.05      0.13   -0.01      0.04
# YearBuilt             -0.05       1.00     -0.16    0.03      0.05
# Diameter               0.13      -0.16      1.00    0.07      0.19
# Length                -0.01       0.03      0.07    1.00      0.11
# Pressure               0.04       0.05      0.19    0.11      1.00
# NumConnections        -0.05      -0.03     -0.11    0.31     -0.10
# NumConnectionsUnder   -0.01       0.01     -0.01    0.02     -0.00
# BoolBridle            -0.09      -0.18      0.09   -0.02     -0.07
#
#                      NumConnections  NumConnectionsUnder  BoolBridle
# PipeId                        -0.05                -0.01       -0.09
# YearBuilt                     -0.03                 0.01       -0.18
# Diameter                      -0.11                -0.01        0.09
# Length                         0.31                 0.02       -0.02
# Pressure                      -0.10                -0.00       -0.07
# NumConnections                 1.00                 0.02       -0.01
# NumConnectionsUnder            0.02                 1.00        0.01
# BoolBridle                    -0.01                 0.01        1.00
# =====================================
# Dataframe covariance %s
#
#                                   PipeId    YearBuilt     Diameter  \
# PipeId              14530921150027338.00 -77216786.03 934255446.23
# YearBuilt                   -77216786.03       146.73      -108.96
# Diameter                    934255446.23      -108.96      3349.02
# Length                     -123925700.01        27.34       336.20
# Pressure                     37295946.35         3.98        77.34
# NumConnections              -11730124.19        -0.75       -14.10
# NumConnectionsUnder            -27840.50         0.00        -0.01
# BoolBridle                   -2791441.94        -0.54         1.31
#
#                            Length    Pressure  NumConnections  \
# PipeId              -123925700.01 37295946.35    -11730124.19
# YearBuilt                   27.34        3.98           -0.75
# Diameter                   336.20       77.34          -14.10
# Length                    6170.72       57.18           52.28
# Pressure                    57.18       47.42           -1.53
# NumConnections              52.28       -1.53            4.67
# NumConnectionsUnder          0.03       -0.00            0.00
# BoolBridle                  -0.44       -0.12           -0.00
#
#                      NumConnectionsUnder  BoolBridle
# PipeId                         -27840.50 -2791441.94
# YearBuilt                           0.00       -0.54
# Diameter                           -0.01        1.31
# Length                              0.03       -0.44
# Pressure                           -0.00       -0.12
# NumConnections                      0.00       -0.00
# NumConnectionsUnder                 0.00        0.00
# BoolBridle                          0.00        0.06
# =====================================
# Dataframe skew %s
#
# PipeId                 0.10
# YearBuilt             -3.38
# Diameter               1.51
# Length                59.72
# Pressure               5.68
# NumConnections         5.52
# NumConnectionsUnder   67.03
# BoolBridle             3.39
# dtype: float64
# =====================================
# Dataframe kurtosis %s
#
# PipeId                   -0.95
# YearBuilt                22.11
# Diameter                  4.41
# Length                17001.24
# Pressure                 42.02
# NumConnections           56.93
# NumConnectionsUnder    5688.23
# BoolBridle                9.52
# dtype: float64
# =====================================

# %% [markdown]
# ## <font color=green> 2.2 Merging inspections and network</font>

# %%
#join Inspection and network datasets on PipeId to create our TRAIN dataset
train = pd.merge(df_inspection, df_network, on='PipeId', how='right')

# %% [markdown]
# This merge is done on the right to enrich the inspections df, adding to each pipe_id all its maintenance history

# %%
train.shape
# Out:
# (6364029, 18)

# %%
df_inspection.shape
# Out:
# (6345344, 7)

# %% [markdown]
# There are 18K null values that do not have information in the df_network so our TRAIN data set is now bigger and we will need to deal with the nulls further down.

# %%
#count null values in train dataset
train.isnull().sum()
# Out:
# PipeId                     0
# MaintenanceId          18685
# InspectionYear         18685
# InspectionDate         18685
# MonthsLastRev          18685
# Severity               18685
# Incidence              18685
# Province                   0
# Town                       0
# YearBuilt                  0
# Material                   0
# GasType                    0
# Diameter                   0
# Length                     0
# Pressure                   0
# NumConnections             0
# NumConnectionsUnder        0
# BoolBridle                 0
# dtype: int64

# %% [markdown]
# This situation will be replicated in the sample_submission file and these features cannot be dropped. According to the EDA and some further feature engineering we will create an optimal strategy for better prediction results

# %%
#point to the folder where the data is stored for Pedro
os.chdir(r"C:\Users\pedro\datathon")

# Loading inspection data
df_sample = pd.read_csv('sample_submission.csv')

# %%
df_sample.shape
# Out:
# (909733, 2)

# %%
df_sample.head()
# Out:
#       PipeId  Incidence
# 0  446859944          0
# 1  428124500          0
# 2  438428871          0
# 3  429034569          0
# 4  411184477          0

# %%
#count the Incidence values in test dataset
df_sample['Incidence'].value_counts()
# Out:
# 0    907964
# 1      1769
# Name: Incidence, dtype: int64

# %% [markdown]
# Sample submission data set is also unbalanced. Does not matter as we have to predict now probabilities

# %% [markdown]
# ## <font color=green> 2.3 Replicating shape in sample submission file</font>

# %% [markdown]
# Creating the sample submission df which will be used to test our model.
#
# This is made of the sample submission with the columns from the network

# %%
#create a dataframe with the unique PipeId from df_sample and a dataframe with the PipeId from df_network 
sample_unique = df_sample['PipeId'].unique()
network_unique = df_network['PipeId'].unique()
#check if all the values in sample_unique are in network_unique
np.all(np.isin(sample_unique, network_unique))
# Out:
# True

# %% [markdown]
# All the PipeId on the df_sample have a PipeId on the network

# %%
#join both datasets on PipeId
test = pd.merge(df_network , df_sample, on='PipeId', how='right')

# %%
test.shape
# Out:
# (909733, 13)

# %%
test.head()
# Out:
#       PipeId  Province     Town  YearBuilt Material      GasType  Diameter  \
# 0  446859944  Valencia  Alginet       2012       PE  Gas natural    110.00
# 1  428124500  Valencia  Alginet       2012       PE  Gas natural    160.00
# 2  438428871  Valencia  Alginet       2012       PE  Gas natural    110.00
# 3  429034569  Valencia  Alginet       2012       PE  Gas natural    110.00
# 4  411184477  Valencia  Alginet       2007       PE  Gas natural    200.00
#
#    Length  Pressure  NumConnections  NumConnectionsUnder  BoolBridle  \
# 0   44.29      0.15               0                    0       False
# 1  110.72      0.15               2                    0       False
# 2   13.57      0.15               0                    0       False
# 3  327.69      0.15               3                    0       False
# 4  932.76      0.15               0                    0       False
#
#    Incidence
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0

# %%
df_sample.head()
# Out:
#       PipeId  Incidence
# 0  446859944          0
# 1  428124500          0
# 2  438428871          0
# 3  429034569          0
# 4  411184477          0

# %%
#Check for null values in test dataset
test_null = test.isnull().sum()    
test_null.head()
# Out:
# PipeId       0
# Province     0
# Town         0
# YearBuilt    0
# Material     0
# dtype: int64

# %% [markdown]
# No null Values in TEST data set

# %%
#creating a subset for altering the dataset after initial EDA
train_copy = train.copy()

# %%
#RAM usage of train_copy
train_copy.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6364029 entries, 0 to 6364028
# Data columns (total 18 columns):
#  #   Column               Dtype
# ---  ------               -----
#  0   PipeId               int64
#  1   MaintenanceId        object
#  2   InspectionYear       float64
#  3   InspectionDate       object
#  4   MonthsLastRev        float64
#  5   Severity             float64
#  6   Incidence            float64
#  7   Province             object
#  8   Town                 object
#  9   YearBuilt            int64
#  10  Material             object
#  11  GasType              object
#  12  Diameter             float64
#  13  Length               float64
#  14  Pressure             float64
#  15  NumConnections       int64
#  16  NumConnectionsUnder  int64
#  17  BoolBridle           bool
# dtypes: bool(1), float64(7), int64(4), object(6)
# memory usage: 3.0 GB

# %%
#deleting old df to save RAM memory
del train
del df_inspection
del df_network
del sample_unique
del network_unique
del test

# %% [markdown]
# Preventing RAM memory issues later on

# %%
#find the columns with null values in train_copy
train_copy.isnull().sum()
# Out:
# PipeId                     0
# MaintenanceId          18685
# InspectionYear         18685
# InspectionDate         18685
# MonthsLastRev          18685
# Severity               18685
# Incidence              18685
# Province                   0
# Town                       0
# YearBuilt                  0
# Material                   0
# GasType                    0
# Diameter                   0
# Length                     0
# Pressure                   0
# NumConnections             0
# NumConnectionsUnder        0
# BoolBridle                 0
# dtype: int64

# %% [markdown]
# <a id='3'></a>
# # <font color=green> 3. Data Wrangling</font>

# %% [markdown]
# Querying the combined df in search of non-coherent data

# %%
#show me a head of train_copy with YearBuilt == 2020
train_copy[train_copy['YearBuilt'] > 2020].head()
# Out:
#           PipeId MaintenanceId  InspectionYear InspectionDate  MonthsLastRev  \
# 64887  185802404           NaN             NaN            NaN            NaN
# 64889  188243116           NaN             NaN            NaN            NaN
# 70787  185839446           NaN             NaN            NaN            NaN
# 70788  186392655           NaN             NaN            NaN            NaN
# 70790  186441076           NaN             NaN            NaN            NaN
#
#        Severity  Incidence Province       Town  YearBuilt Material  \
# 64887       NaN        NaN   Girona  Puigcerda       2021       PN
# 64889       NaN        NaN   Girona  Puigcerda       2021       PN
# 70787       NaN        NaN   Girona     Girona       2021       PN
# 70788       NaN        NaN   Girona     Girona       2021       PN
# 70790       NaN        NaN   Girona     Girona       2021       PN
#
#            GasType  Diameter  Length  Pressure  NumConnections  \
# 64887  Gas natural    110.00   12.01      0.15               1
# 64889  Gas natural     90.00   11.82      0.15               1
# 70787  Gas natural    110.00    5.10      0.03               1
# 70788  Gas natural     63.00    4.51      0.03               1
# 70790  Gas natural     63.00    0.29      0.03               0
#
#        NumConnectionsUnder  BoolBridle
# 64887                    0        True
# 64889                    0        True
# 70787                    0        True
# 70788                    0        True
# 70790                    0        True

# %%
#count the PipeID that have YearBuilt equal to 2021 and InspectionYear equal to NaN
train_copy[(train_copy['YearBuilt'] > 2020) & (train_copy['InspectionYear'].isnull())].shape
# Out:
# (2026, 18)

# %%
train_copy[(train_copy['YearBuilt'] > 2020) & (train_copy['InspectionYear'].isnull())].to_csv('train_copy_2020.csv')

# %% [markdown]
# There are 2026 pipes that were built after 2020 in the train data set, these came from the network data set and will be considered new pipes that do not have inspection data yet. We will assume that the inspection year for those was the year of installation (you inspect them when you install them).
#
# This is to be done in the submission file. To know which pipes to add 2020, we export a subset file containing this information. After this we delete these rows

# %%
#dropping the rows with YearBuilt > 2020 and InspectionYear == NaN
train_copy = train_copy.drop(train_copy[(train_copy['YearBuilt'] > 2020) & (train_copy['InspectionYear'].isnull())].index)

#count the PipeID that have YearBuilt equal to 2021 and InspectionYear equal to NaN
train_copy[(train_copy['YearBuilt'] > 2020) & (train_copy['InspectionYear'].isnull())].shape
# Out:
# (0, 18)

# %%
#nulls for InspectionYear for every year in train_copy
train_copy.groupby('InspectionYear')['InspectionYear'].count()
# Out:
# InspectionYear
# 2010.00     93518
# 2011.00    528113
# 2012.00    611594
# 2013.00    581559
# 2014.00    593223
# 2015.00    617187
# 2016.00    627667
# 2017.00    684715
# 2018.00    654861
# 2019.00    694584
# 2020.00    656878
# 2021.00      1445
# Name: InspectionYear, dtype: int64

# %%
#YearBuilt values for the null vales in InspectionYear
train_copy[train_copy['InspectionYear'].isnull()]['YearBuilt'].value_counts()
# Out:
# 2020    3290
# 2019    2654
# 2016    1144
# 2015     873
# 2018     855
# 2017     806
# 2002     533
# 1998     343
# 2007     341
# 2008     339
# 2001     339
# 2005     338
# 2006     338
# 2004     316
# 2014     311
# 2003     295
# 2009     293
# 2012     250
# 2000     248
# 1999     229
# 2013     222
# 1997     207
# 1996     205
# 2010     175
# 1995     173
# 2011     168
# 1993     149
# 1994     126
# 1992     110
# 1950     105
# 1987     101
# 1990      92
# 1991      88
# 1988      86
# 1989      80
# 1986      63
# 1901      46
# 1975      35
# 1984      34
# 1985      33
# 1982      27
# 1983      26
# 1974      25
# 1977      21
# 1978      19
# 1976      13
# 1963      13
# 1979      11
# 1973      11
# 1972      10
# 1981      10
# 1980      10
# 1968       9
# 1970       8
# 1971       7
# 1969       2
# 1965       2
# 1966       1
# 1967       1
# Name: YearBuilt, dtype: int64

# %% [markdown]
# There are very old pipes in this dataframe. We will deal with them as outliers later in the notebook.
#
# Last, we remove the null values for all those pipes that appear in network but not in inspections

# %%
#remove from train_copy the rows where InspectionYear is equal to NaN and yearBuilt is not null
train_copy = train_copy[~((train_copy['InspectionYear'].isnull()) & (train_copy['YearBuilt'].notnull()))]

# %% [markdown]
# We do not have info for these pipes so we will remove them all as it is impossible to find out the year built

# %%
train_copy.isnull().sum()
# Out:
# PipeId                 0
# MaintenanceId          0
# InspectionYear         0
# InspectionDate         0
# MonthsLastRev          0
# Severity               0
# Incidence              0
# Province               0
# Town                   0
# YearBuilt              0
# Material               0
# GasType                0
# Diameter               0
# Length                 0
# Pressure               0
# NumConnections         0
# NumConnectionsUnder    0
# BoolBridle             0
# dtype: int64

# %%
#Count of pipes with YearBuilt higher than InspectionYear 
train_copy[(train_copy['YearBuilt'] > train_copy['InspectionYear'])].shape

#show a head of this query
train_copy[(train_copy['YearBuilt'] > train_copy['InspectionYear'])].head(5)
# Out:
# (7672, 18)
#          PipeId MaintenanceId  InspectionYear InspectionDate  MonthsLastRev  \
# 6426    4189344  ZRV-00003409         2014.00     2014-05-13          72.00
# 6428    4189348  ZRV-00003409         2014.00     2014-05-13          72.00
# 6430    4189349  ZRV-00003409         2014.00     2014-05-13          72.00
# 7468  307145056  ZRV-00003409         2012.00     2012-05-16          24.00
# 7469  307145056  ZRV-00003409         2014.00     2014-05-09          24.00
#
#       Severity  Incidence Province    Town  YearBuilt Material      GasType  \
# 6426      4.00       0.00  Córdoba  Lucena       2019       PE  Gas natural
# 6428      4.00       0.00  Córdoba  Lucena       2019       PE  Gas natural
# 6430      4.00       0.00  Córdoba  Lucena       2019       PE  Gas natural
# 7468      4.00       0.00  Córdoba  Lucena       2018       PE  Gas natural
# 7469      4.00       0.00  Córdoba  Lucena       2018       PE  Gas natural
#
#       Diameter  Length  Pressure  NumConnections  NumConnectionsUnder  \
# 6426     90.00    1.07      0.15               0                    0
# 6428     90.00  195.36      0.15               0                    0
# 6430     90.00    8.47      0.15               1                    0
# 7468     90.00    9.74      0.15               0                    0
# 7469     90.00    9.74      0.15               0                    0
#
#       BoolBridle
# 6426       False
# 6428       False
# 6430       False
# 7468       False
# 7469       False

# %% [markdown]
# There seems to be an inconsistency with these pipes as these have been inspected before they were built!  We delete these as well

# %%
#drop the rows where YearBuilt is higher than InspectionYear
# train_copy = train_copy.drop(train_copy[(train_copy['YearBuilt'] > train_copy['InspectionYear'])].index)
#for rows where YearBuilt is higher than InspectionYear, replace YearBuilt with InspectionYear - 2
train_copy['YearBuilt'] = np.where(train_copy['YearBuilt'] > train_copy['InspectionYear'], train_copy['YearBuilt'].mean(), train_copy['YearBuilt'])
#If Yearbuilt is smaller than 1970, set it to 1970
train_copy.loc[(train_copy['YearBuilt'] < 1970), 'YearBuilt'] = 1970

# %% [markdown]
# Our dataframe is now clean and ready to proceed to feature engineering

# %%
#count the PipeId in inspection dataset that YearBuilt is equal to 2020 and inspection year is equal to 2021
train_copy[(train_copy['YearBuilt'] > 2020) & (train_copy['InspectionYear'] == 2021)].shape
# Out:
# (0, 18)

# %%
train_copy.shape
# Out:
# (6345344, 18)

# %% [markdown]
# <a id='4'></a>
# # <font color=green> 4. Feature Engineering</font>

# %% [markdown]
# As a result of merging both datasets we now have pipeline duplicates per each maintenace_id operation. These contain valuable data at each point in time. At this point we have two approaches:
#
# - Engineer Features as aggregates and then deleting duplicates to keep one PipeId
#     - This approach will give out these valuable data in favour of aggregates which do not always capture everything that has happened in the past accurately
#
# - Create new features that add on these snapshots. We continue with this approach

# %%
#for a row with same PipeId and InspectionYear, create a new column counting the number of MaintenanceId per Pipe and name it No_Inspections
train_copy['No_Inspections'] = train_copy.groupby(['PipeId', 'InspectionYear'])['MaintenanceId'].transform('count')
#querying rows with different InspectionYear 
train_copy[train_copy['InspectionYear'] != train_copy['YearBuilt']].head(10)
# Out:
#    PipeId MaintenanceId  InspectionYear InspectionDate  MonthsLastRev  \
# 0  489616  ZRV-00003385         2013.00     2013-05-08          16.00
# 1  489616  ZRV-00003385         2015.00     2015-03-04          22.00
# 2  489616  ZRV-00003385         2016.00     2017-01-12          22.00
# 3  489616  ZRV-00003385         2018.00     2018-12-19          23.00
# 4  489616  ZRV-00003385         2020.00     2020-12-05          24.00
# 5  489645  ZRV-00003385         2013.00     2013-05-08          16.00
# 6  489645  ZRV-00003385         2015.00     2015-03-24          22.00
# 7  489645  ZRV-00003385         2016.00     2017-01-12          22.00
# 8  489645  ZRV-00003385         2018.00     2018-12-19          23.00
# 9  489645  ZRV-00003385         2020.00     2020-12-05          24.00
#
#    Severity  Incidence     Province                   Town  YearBuilt  \
# 0      4.00       0.00  Ciudad Real  Torralba de Calatrava    2012.00
# 1      4.00       0.00  Ciudad Real  Torralba de Calatrava    2012.00
# 2      4.00       0.00  Ciudad Real  Torralba de Calatrava    2012.00
# 3      4.00       0.00  Ciudad Real  Torralba de Calatrava    2012.00
# 4      4.00       0.00  Ciudad Real  Torralba de Calatrava    2012.00
# 5      4.00       0.00  Ciudad Real  Torralba de Calatrava    2012.00
# 6      4.00       0.00  Ciudad Real  Torralba de Calatrava    2012.00
# 7      4.00       0.00  Ciudad Real  Torralba de Calatrava    2012.00
# 8      4.00       0.00  Ciudad Real  Torralba de Calatrava    2012.00
# 9      4.00       0.00  Ciudad Real  Torralba de Calatrava    2012.00
#
#   Material      GasType  Diameter  Length  Pressure  NumConnections  \
# 0       PE  Gas natural     63.00    7.79      0.40               0
# 1       PE  Gas natural     63.00    7.79      0.40               0
# 2       PE  Gas natural     63.00    7.79      0.40               0
# 3       PE  Gas natural     63.00    7.79      0.40               0
# 4       PE  Gas natural     63.00    7.79      0.40               0
# 5       PE  Gas natural     90.00    2.08      0.40               0
# 6       PE  Gas natural     90.00    2.08      0.40               0
# 7       PE  Gas natural     90.00    2.08      0.40               0
# 8       PE  Gas natural     90.00    2.08      0.40               0
# 9       PE  Gas natural     90.00    2.08      0.40               0
#
#    NumConnectionsUnder  BoolBridle  No_Inspections
# 0                    0       False               1
# 1                    0       False               1
# 2                    0       False               1
# 3                    0       False               1
# 4                    0       False               1
# 5                    0       False               1
# 6                    0       False               1
# 7                    0       False               1
# 8                    0       False               1
# 9                    0       False               1

# %%
#for a same PipeId, create a new column No_Inspections_Year summing the previous value in No_Inspections starting in 2010
train_copy['No_Inspections_Year'] = train_copy.groupby(['PipeId'])['No_Inspections'].transform(lambda x: x.cumsum())
#querying rows with different InspectionYear
train_copy[train_copy['InspectionYear'] != train_copy['YearBuilt']].head(10)
# Out:
#    PipeId MaintenanceId  InspectionYear InspectionDate  MonthsLastRev  \
# 0  489616  ZRV-00003385         2013.00     2013-05-08          16.00
# 1  489616  ZRV-00003385         2015.00     2015-03-04          22.00
# 2  489616  ZRV-00003385         2016.00     2017-01-12          22.00
# 3  489616  ZRV-00003385         2018.00     2018-12-19          23.00
# 4  489616  ZRV-00003385         2020.00     2020-12-05          24.00
# 5  489645  ZRV-00003385         2013.00     2013-05-08          16.00
# 6  489645  ZRV-00003385         2015.00     2015-03-24          22.00
# 7  489645  ZRV-00003385         2016.00     2017-01-12          22.00
# 8  489645  ZRV-00003385         2018.00     2018-12-19          23.00
# 9  489645  ZRV-00003385         2020.00     2020-12-05          24.00
#
#    Severity  Incidence     Province                   Town  YearBuilt  \
# 0      4.00       0.00  Ciudad Real  Torralba de Calatrava    2012.00
# 1      4.00       0.00  Ciudad Real  Torralba de Calatrava    2012.00
# 2      4.00       0.00  Ciudad Real  Torralba de Calatrava    2012.00
# 3      4.00       0.00  Ciudad Real  Torralba de Calatrava    2012.00
# 4      4.00       0.00  Ciudad Real  Torralba de Calatrava    2012.00
# 5      4.00       0.00  Ciudad Real  Torralba de Calatrava    2012.00
# 6      4.00       0.00  Ciudad Real  Torralba de Calatrava    2012.00
# 7      4.00       0.00  Ciudad Real  Torralba de Calatrava    2012.00
# 8      4.00       0.00  Ciudad Real  Torralba de Calatrava    2012.00
# 9      4.00       0.00  Ciudad Real  Torralba de Calatrava    2012.00
#
#   Material      GasType  Diameter  Length  Pressure  NumConnections  \
# 0       PE  Gas natural     63.00    7.79      0.40               0
# 1       PE  Gas natural     63.00    7.79      0.40               0
# 2       PE  Gas natural     63.00    7.79      0.40               0
# 3       PE  Gas natural     63.00    7.79      0.40               0
# 4       PE  Gas natural     63.00    7.79      0.40               0
# 5       PE  Gas natural     90.00    2.08      0.40               0
# 6       PE  Gas natural     90.00    2.08      0.40               0
# 7       PE  Gas natural     90.00    2.08      0.40               0
# 8       PE  Gas natural     90.00    2.08      0.40               0
# 9       PE  Gas natural     90.00    2.08      0.40               0
#
#    NumConnectionsUnder  BoolBridle  No_Inspections  No_Inspections_Year
# 0                    0       False               1                    1
# 1                    0       False               1                    2
# 2                    0       False               1                    3
# 3                    0       False               1                    4
# 4                    0       False               1                    5
# 5                    0       False               1                    1
# 6                    0       False               1                    2
# 7                    0       False               1                    3
# 8                    0       False               1                    4
# 9                    0       False               1                    5

# %%
#query pipeid 489616
train_copy[train_copy['PipeId'] == 489645].head(10)
# Out:
#    PipeId MaintenanceId  InspectionYear InspectionDate  MonthsLastRev  \
# 5  489645  ZRV-00003385         2013.00     2013-05-08          16.00
# 6  489645  ZRV-00003385         2015.00     2015-03-24          22.00
# 7  489645  ZRV-00003385         2016.00     2017-01-12          22.00
# 8  489645  ZRV-00003385         2018.00     2018-12-19          23.00
# 9  489645  ZRV-00003385         2020.00     2020-12-05          24.00
#
#    Severity  Incidence     Province                   Town  YearBuilt  \
# 5      4.00       0.00  Ciudad Real  Torralba de Calatrava    2012.00
# 6      4.00       0.00  Ciudad Real  Torralba de Calatrava    2012.00
# 7      4.00       0.00  Ciudad Real  Torralba de Calatrava    2012.00
# 8      4.00       0.00  Ciudad Real  Torralba de Calatrava    2012.00
# 9      4.00       0.00  Ciudad Real  Torralba de Calatrava    2012.00
#
#   Material      GasType  Diameter  Length  Pressure  NumConnections  \
# 5       PE  Gas natural     90.00    2.08      0.40               0
# 6       PE  Gas natural     90.00    2.08      0.40               0
# 7       PE  Gas natural     90.00    2.08      0.40               0
# 8       PE  Gas natural     90.00    2.08      0.40               0
# 9       PE  Gas natural     90.00    2.08      0.40               0
#
#    NumConnectionsUnder  BoolBridle  No_Inspections  No_Inspections_Year
# 5                    0       False               1                    1
# 6                    0       False               1                    2
# 7                    0       False               1                    3
# 8                    0       False               1                    4
# 9                    0       False               1                    5

# %%
#query pipe 188488937 returning only pipid, inspection year, and no_inspection_year
train_copy[train_copy['PipeId'] == 188488937][['PipeId', 'InspectionYear', 'No_Inspections_Year']].head(10)
# Out:
#            PipeId  InspectionYear  No_Inspections_Year
# 112126  188488937         2010.00                    1
# 112127  188488937         2012.00                    2
# 112128  188488937         2014.00                    3
# 112129  188488937         2016.00                    4
# 112130  188488937         2018.00                    5
# 112131  188488937         2020.00                    6

# %%
#drop No_Inspections column
train_copy = train_copy.drop(['No_Inspections'], axis=1)

# %%
#chaning name to No_Inspections_Year to No_Inspections
train_copy = train_copy.rename(columns={'No_Inspections_Year': 'No_Inspections'})

# %% [markdown]
# We now have the cummulative number of inspections for that pipe Id per year. If in a previous year there has been an inspection but in the consecutive not, this value will only sum the 1s

# %%
#for a row with same PipeId and InspectionYear, create a new column suming the number of Incidences per Pipe and name it No_Incidences
train_copy['No_Incidences'] = train_copy.groupby(['PipeId', 'InspectionYear'])['Incidence'].transform('sum')
#querying rows with different InspectionYear where Incidence is equal to 1
train_copy[(train_copy['InspectionYear'] != train_copy['YearBuilt']) & (train_copy['Incidence'] == 1)].head(1)
# Out:
#          PipeId MaintenanceId  InspectionYear InspectionDate  MonthsLastRev  \
# 12371  35790261  ZRV-00007259         2018.00     2018-02-23           9.00
#
#        Severity  Incidence Province    Town  YearBuilt Material      GasType  \
# 12371      3.00       1.00  Córdoba  Lucena    2016.00       PE  Gas natural
#
#        Diameter  Length  Pressure  NumConnections  NumConnectionsUnder  \
# 12371     32.00   87.83      0.15              12                    0
#
#        BoolBridle  No_Inspections  No_Incidences
# 12371       False               1           1.00

# %%
#for a same PipeId, create a new column No_Incidences_Total summing the previous value in No_Incidences starting in 2010
train_copy['No_Incidences_Total'] = train_copy.groupby(['PipeId'])['No_Incidences'].transform(lambda x: x.cumsum())
train_copy['No_Previous_Incidences']=train_copy['No_Incidences_Total']-train_copy['Incidence']

# %%
#querying rows with No_Incidences_Total > 1
train_copy[train_copy['No_Incidences_Total'] > 3].head(10)
# Out:
#             PipeId MaintenanceId  InspectionYear InspectionDate  \
# 2420311  292759233  ZRV-00003772         2020.00     2020-02-05
# 2421638  292843631  ZRV-00003772         2020.00     2020-02-04
# 3686857  308090921  ZRV-00003776         2020.00     2020-11-20
# 3802537  297684002  ZRV-00003771         2018.00     2018-07-25
# 3802538  297684002  ZRV-00003771         2020.00     2020-06-03
# 4393417   12688060  ZRV-00003720         2017.00     2017-02-28
# 4393418   12688060  ZRV-00003720         2019.00     2019-01-09
# 4393419   12688060  ZRV-00003720         2020.00     2020-11-24
#
#          MonthsLastRev  Severity  Incidence Province    Town  YearBuilt  \
# 2420311          22.00      1.00       1.00   Madrid  Madrid    1995.00
# 2421638          22.00      3.00       1.00   Madrid  Madrid    1992.00
# 3686857          30.00      3.00       1.00   Madrid  Madrid    1995.00
# 3802537          22.00      3.00       1.00   Madrid  Madrid    1995.00
# 3802538          23.00      4.00       0.00   Madrid  Madrid    1995.00
# 4393417          21.00      3.00       1.00   Madrid  Madrid    2014.00
# 4393418          23.00      2.00       1.00   Madrid  Madrid    2014.00
# 4393419          22.00      4.00       0.00   Madrid  Madrid    2014.00
#
#         Material      GasType  Diameter  Length  Pressure  NumConnections  \
# 2420311       PE  Gas natural    200.00   31.13      0.03               5
# 2421638       FD  Gas natural    250.00  122.41      0.03              11
# 3686857       PE  Gas natural    200.00   83.47      0.03              11
# 3802537       PE  Gas natural    160.00  139.25      0.03              15
# 3802538       PE  Gas natural    160.00  139.25      0.03              15
# 4393417       FD  Gas natural    250.00  125.87      0.03              16
# 4393418       FD  Gas natural    250.00  125.87      0.03              16
# 4393419       FD  Gas natural    250.00  125.87      0.03              16
#
#          NumConnectionsUnder  BoolBridle  No_Inspections  No_Incidences  \
# 2420311                    0       False               6           1.00
# 2421638                    0        True               6           1.00
# 3686857                    0       False               6           1.00
# 3802537                    0       False               5           1.00
# 3802538                    0       False               6           0.00
# 4393417                    0        True               4           1.00
# 4393418                    0        True               5           1.00
# 4393419                    0        True               6           0.00
#
#          No_Incidences_Total  No_Previous_Incidences
# 2420311                 4.00                    3.00
# 2421638                 4.00                    3.00
# 3686857                 4.00                    3.00
# 3802537                 4.00                    3.00
# 3802538                 4.00                    4.00
# 4393417                 4.00                    3.00
# 4393418                 5.00                    4.00
# 4393419                 5.00                    5.00

# %%
train_copy[train_copy['PipeId'] == 188488937][['PipeId', 'InspectionYear', "Incidence", 'No_Incidences_Total','No_Previous_Incidences']].head(10)
# Out:
#            PipeId  InspectionYear  Incidence  No_Incidences_Total  \
# 112126  188488937         2010.00       0.00                 0.00
# 112127  188488937         2012.00       1.00                 1.00
# 112128  188488937         2014.00       0.00                 1.00
# 112129  188488937         2016.00       0.00                 1.00
# 112130  188488937         2018.00       0.00                 1.00
# 112131  188488937         2020.00       1.00                 2.00
#
#         No_Previous_Incidences
# 112126                    0.00
# 112127                    0.00
# 112128                    1.00
# 112129                    1.00
# 112130                    1.00
# 112131                    1.00

# %% [markdown]
# Similarly, we capture each snapshot cumulative value to understand how many incidences has this pipe registered in the past

# %%
train_copy.dtypes
# Out:
# PipeId                      int64
# MaintenanceId              object
# InspectionYear            float64
# InspectionDate             object
# MonthsLastRev             float64
# Severity                  float64
# Incidence                 float64
# Province                   object
# Town                       object
# YearBuilt                 float64
# Material                   object
# GasType                    object
# Diameter                  float64
# Length                    float64
# Pressure                  float64
# NumConnections              int64
# NumConnectionsUnder         int64
# BoolBridle                   bool
# No_Inspections              int64
# No_Incidences             float64
# No_Incidences_Total       float64
# No_Previous_Incidences    float64
# dtype: object

# %%
#convert to int 64 the columns InspectionYear, MonthsLastRev, Severity, Incidence, No_Incidences, No_Incidences_Total, Diameter
train_copy['InspectionYear'] = train_copy['InspectionYear'].astype('int64')
train_copy['MonthsLastRev'] = train_copy['MonthsLastRev'].astype('int64')
train_copy['Severity'] = train_copy['Severity'].astype('int64')
train_copy['Incidence'] = train_copy['Incidence'].astype('int64')
train_copy['No_Incidences'] = train_copy['No_Incidences'].astype('int64')
train_copy['No_Incidences_Total'] = train_copy['No_Incidences_Total'].astype('int64')
train_copy['Diameter'] = train_copy['Diameter'].astype('int64')

# %% [markdown]
# Some data types are formatted as float and occupy more memory. We convert these into integers

# %%
train_copy.columns
# Out:
# Index(['PipeId', 'MaintenanceId', 'InspectionYear', 'InspectionDate',
#        'MonthsLastRev', 'Severity', 'Incidence', 'Province', 'Town',
#        'YearBuilt', 'Material', 'GasType', 'Diameter', 'Length', 'Pressure',
#        'NumConnections', 'NumConnectionsUnder', 'BoolBridle', 'No_Inspections',
#        'No_Incidences', 'No_Incidences_Total', 'No_Previous_Incidences'],
#       dtype='object')

# %%
#query rows where InspectionYear is more than 2020
train_copy[train_copy['InspectionYear'] > 2020].head(5)
# Out:
#             PipeId MaintenanceId  InspectionYear InspectionDate  \
# 1568869  188022953  ZRV-00002047            2021     2020-12-28
# 1568895  188022999  ZRV-00002047            2021     2020-12-28
# 1568901  188023006  ZRV-00002047            2021     2020-12-28
# 1568907  188023012  ZRV-00002047            2021     2020-12-28
# 1568978  188023171  ZRV-00002047            2021     2020-12-28
#
#          MonthsLastRev  Severity  Incidence   Province           Town  \
# 1568869             23         4          0  Barcelona  Premia de Mar
# 1568895             23         4          0  Barcelona  Premia de Mar
# 1568901             23         4          0  Barcelona  Premia de Mar
# 1568907             23         4          0  Barcelona  Premia de Mar
# 1568978             23         4          0  Barcelona  Premia de Mar
#
#          YearBuilt Material      GasType  Diameter  Length  Pressure  \
# 1568869    1980.00       FD  Gas natural       100    2.81      0.03
# 1568895    1993.00       PE  Gas natural       110   28.57      0.03
# 1568901    1993.00       PE  Gas natural       110    3.11      0.03
# 1568907    1993.00       PE  Gas natural       110    6.82      0.03
# 1568978    1991.00       PE  Gas natural       160   36.39      0.03
#
#          NumConnections  NumConnectionsUnder  BoolBridle  No_Inspections  \
# 1568869               0                    0        True               6
# 1568895               1                    0       False               6
# 1568901               0                    0       False               6
# 1568907               0                    0       False               6
# 1568978               0                    0       False               6
#
#          No_Incidences  No_Incidences_Total  No_Previous_Incidences
# 1568869              0                    0                    0.00
# 1568895              0                    0                    0.00
# 1568901              0                    0                    0.00
# 1568907              0                    0                    0.00
# 1568978              0                    0                    0.00

# %% [markdown]
# Checking if we have values higher than 2020 for next steps. We do have some, we will check if these are in the sample submission

# %%
#check if df_sample PipeId is in train copy when InspectionYear > 2020 and count the number of rows
df_sample[df_sample['PipeId'].isin(train_copy[train_copy['InspectionYear'] > 2020]['PipeId'])].shape
# Out:
# (0, 2)

# %% [markdown]
# They are not, we delete these from our train file. We are tasked with predicting the future. Having 2020 values will bias the model

# %%
#delete the rows where InspectionYear is more than 2020
train_copy = train_copy.drop(train_copy[train_copy['InspectionYear'] > 2020].index)

# %%
train_copy.shape
# Out:
# (6343899, 22)

# %%
#create a column named average_severity_pipe that calculates the average severity per pipe aggregating all severities
train_copy['average_severity_pipe'] = train_copy.groupby('PipeId')['Severity'].transform('mean')
#show head of rows only where mean has a decimal value
train_copy[train_copy['average_severity_pipe'] % 1 != 0].head(3)
# Out:
#          PipeId MaintenanceId  InspectionYear InspectionDate  MonthsLastRev  \
# 12371  35790261  ZRV-00007259            2018     2018-02-23              9
# 12372  35790261  ZRV-00003409            2020     2020-05-20             27
# 12725   3663205  ZRV-00003435            2013     2013-05-15             16
#
#        Severity  Incidence Province     Town  YearBuilt Material      GasType  \
# 12371         3          1  Córdoba   Lucena    2016.00       PE  Gas natural
# 12372         4          0  Córdoba   Lucena    2016.00       PE  Gas natural
# 12725         3          1  Granada  Granada    2012.00       PE  Gas natural
#
#        Diameter  Length  Pressure  NumConnections  NumConnectionsUnder  \
# 12371        32   87.83      0.15              12                    0
# 12372        32   87.83      0.15              12                    0
# 12725       110  194.41      0.40               8                    0
#
#        BoolBridle  No_Inspections  No_Incidences  No_Incidences_Total  \
# 12371       False               1              1                    1
# 12372       False               2              0                    1
# 12725       False               1              1                    1
#
#        No_Previous_Incidences  average_severity_pipe
# 12371                    0.00                   3.50
# 12372                    1.00                   3.50
# 12725                    0.00                   3.75

# %%
#create a column taking average severity and number of total incidences per pipe multiplying them and naming it as risk_(s*i)
train_copy['relative_risk'] = train_copy['average_severity_pipe'] * train_copy['No_Previous_Incidences']
#show shape of relative_risk = 0
train_copy[train_copy['relative_risk'] == 0].shape
# Out:
# (6321119, 24)

# %% [markdown]
# This new column allows us to have a measure of risk by adding the mean aggregate of severity for an specific pipe and the aggregate number of incidents that we just created above. We can see most of the pipes have a relative risk of 0 as the differnece between total shape and relative risk safe 6336227-6302420.
#
# The difference is 33807 pipes with risk and the rest with a risk of 0

# %%
train_copy.shape
# Out:
# (6343899, 24)

# %%
#show head of rows only where Risk_S*I is greater than 0
train_copy[train_copy['relative_risk'] > 12].head(2)
# Out:
#             PipeId MaintenanceId  InspectionYear InspectionDate  \
# 3802538  297684002  ZRV-00003771            2020     2020-06-03
# 4393419   12688060  ZRV-00003720            2020     2020-11-24
#
#          MonthsLastRev  Severity  Incidence Province    Town  YearBuilt  \
# 3802538             23         4          0   Madrid  Madrid    1995.00
# 4393419             22         4          0   Madrid  Madrid    2014.00
#
#         Material      GasType  Diameter  Length  Pressure  NumConnections  \
# 3802538       PE  Gas natural       160  139.25      0.03              15
# 4393419       FD  Gas natural       250  125.87      0.03              16
#
#          NumConnectionsUnder  BoolBridle  No_Inspections  No_Incidences  \
# 3802538                    0       False               6              0
# 4393419                    0        True               6              0
#
#          No_Incidences_Total  No_Previous_Incidences  average_severity_pipe  \
# 3802538                    4                    4.00                   3.33
# 4393419                    5                    5.00                   3.00
#
#          relative_risk
# 3802538          13.33
# 4393419          15.00

# %% [markdown]
# PE and FD tendo to fail more when getting closer to 30 years old

# %%
#Built year for material FD
train_copy[train_copy['Material'] == 'FD']['YearBuilt'].mean()
# Out:
# 1984.1827224692627

# %%
train_copy[train_copy['Material'] == 'PE']['YearBuilt'].mean()
# Out:
# 2002.2909067940466

# %% [markdown]
# We can see that  for a high risk factor, the most common materials are PE and FD with a mean of year built in the 90s. The pipes do not seem to be abandoned as the last year of inspection seems to be 2010.
#
# Also, FD has an outlier for pipes built and the beginning of 1900

# %%
train_copy.head(2)
# Out:
#    PipeId MaintenanceId  InspectionYear InspectionDate  MonthsLastRev  \
# 0  489616  ZRV-00003385            2013     2013-05-08             16
# 1  489616  ZRV-00003385            2015     2015-03-04             22
#
#    Severity  Incidence     Province                   Town  YearBuilt  \
# 0         4          0  Ciudad Real  Torralba de Calatrava    2012.00
# 1         4          0  Ciudad Real  Torralba de Calatrava    2012.00
#
#   Material      GasType  Diameter  Length  Pressure  NumConnections  \
# 0       PE  Gas natural        63    7.79      0.40               0
# 1       PE  Gas natural        63    7.79      0.40               0
#
#    NumConnectionsUnder  BoolBridle  No_Inspections  No_Incidences  \
# 0                    0       False               1              0
# 1                    0       False               2              0
#
#    No_Incidences_Total  No_Previous_Incidences  average_severity_pipe  \
# 0                    0                    0.00                   4.00
# 1                    0                    0.00                   4.00
#
#    relative_risk
# 0           0.00
# 1           0.00

# %% [markdown]
# Dropping some columns not needed after creating the new features

# %%
#delete columns No_Incidences, No_Incidents
train_copy = train_copy.drop(['No_Incidences'], axis=1)

# %%
#create a new column taking Risk_S*I and dividing it by No_Inspections naming it as Risk_S*I/Inspections and placing it in 6th position
train_copy['preventive_maintenance_rate'] = train_copy['relative_risk'] / train_copy['No_Inspections']
cols = list(train_copy.columns.values)

#show head of rows only where Risk_S*I/Inspections is greater than 0
train_copy[train_copy['preventive_maintenance_rate'] > 0].head(5)
# Out:
#           PipeId MaintenanceId  InspectionYear InspectionDate  MonthsLastRev  \
# 12372   35790261  ZRV-00003409            2020     2020-05-20             27
# 12726    3663205  ZRV-00003435            2015     2015-05-26             24
# 12727    3663205  ZRV-00003435            2017     2017-05-10             24
# 12728    3663205  ZRV-00003435            2019     2019-05-10             24
# 15124  228066029  ZRV-00003435            2019     2019-05-22             24
#
#        Severity  Incidence Province     Town  YearBuilt Material      GasType  \
# 12372         4          0  Córdoba   Lucena    2016.00       PE  Gas natural
# 12726         4          0  Granada  Granada    2012.00       PE  Gas natural
# 12727         4          0  Granada  Granada    2012.00       PE  Gas natural
# 12728         4          0  Granada  Granada    2012.00       PE  Gas natural
# 15124         4          0  Granada  Granada    1998.00       PE  Gas natural
#
#        Diameter  Length  Pressure  NumConnections  NumConnectionsUnder  \
# 12372        32   87.83      0.15              12                    0
# 12726       110  194.41      0.40               8                    0
# 12727       110  194.41      0.40               8                    0
# 12728       110  194.41      0.40               8                    0
# 15124       200  171.11      0.15               5                    0
#
#        BoolBridle  No_Inspections  No_Incidences_Total  \
# 12372       False               2                    1
# 12726       False               2                    1
# 12727       False               3                    1
# 12728       False               4                    1
# 15124       False               5                    1
#
#        No_Previous_Incidences  average_severity_pipe  relative_risk  \
# 12372                    1.00                   3.50           3.50
# 12726                    1.00                   3.75           3.75
# 12727                    1.00                   3.75           3.75
# 12728                    1.00                   3.75           3.75
# 15124                    1.00                   3.80           3.80
#
#        preventive_maintenance_rate
# 12372                         1.75
# 12726                         1.88
# 12727                         1.25
# 12728                         0.94
# 15124                         0.76

# %% [markdown]
# In this new column we can see a dimension of how good it has been previous preventive maintenance  by dividing the relative risk factor (mean average risk per pipe*No_incidents) / No_inspections.
#
# The higher this index, the less maintenance it has undergone, hence the risk is not being mitigated on an active basis
# This graph can help us allocate better the maintenance in our business case using the Paretto rule

# %%
#graph a treemap showing the Province and Towns where preventive_maintenance_rate is higher than 2
fig = px.treemap(train_copy[train_copy['preventive_maintenance_rate'] > 2], path=['Province', 'Town'], values='preventive_maintenance_rate')
fig.show()

# %%
#creating a new column named probability with No_Incidents divided by Inspections
train_copy['Probability_rate'] = train_copy['No_Previous_Incidences'] / train_copy['No_Inspections']

#show head of rows only where Probability is greater than 0
train_copy[train_copy['Probability_rate'] > 0].head(5)
# Out:
#           PipeId MaintenanceId  InspectionYear InspectionDate  MonthsLastRev  \
# 12372   35790261  ZRV-00003409            2020     2020-05-20             27
# 12726    3663205  ZRV-00003435            2015     2015-05-26             24
# 12727    3663205  ZRV-00003435            2017     2017-05-10             24
# 12728    3663205  ZRV-00003435            2019     2019-05-10             24
# 15124  228066029  ZRV-00003435            2019     2019-05-22             24
#
#        Severity  Incidence Province     Town  YearBuilt Material      GasType  \
# 12372         4          0  Córdoba   Lucena    2016.00       PE  Gas natural
# 12726         4          0  Granada  Granada    2012.00       PE  Gas natural
# 12727         4          0  Granada  Granada    2012.00       PE  Gas natural
# 12728         4          0  Granada  Granada    2012.00       PE  Gas natural
# 15124         4          0  Granada  Granada    1998.00       PE  Gas natural
#
#        Diameter  Length  Pressure  NumConnections  NumConnectionsUnder  \
# 12372        32   87.83      0.15              12                    0
# 12726       110  194.41      0.40               8                    0
# 12727       110  194.41      0.40               8                    0
# 12728       110  194.41      0.40               8                    0
# 15124       200  171.11      0.15               5                    0
#
#        BoolBridle  No_Inspections  No_Incidences_Total  \
# 12372       False               2                    1
# 12726       False               2                    1
# 12727       False               3                    1
# 12728       False               4                    1
# 15124       False               5                    1
#
#        No_Previous_Incidences  average_severity_pipe  relative_risk  \
# 12372                    1.00                   3.50           3.50
# 12726                    1.00                   3.75           3.75
# 12727                    1.00                   3.75           3.75
# 12728                    1.00                   3.75           3.75
# 15124                    1.00                   3.80           3.80
#
#        preventive_maintenance_rate  Probability_rate
# 12372                         1.75              0.50
# 12726                         1.88              0.50
# 12727                         1.25              0.33
# 12728                         0.94              0.25
# 15124                         0.76              0.20

# %% [markdown]
# Having created risk and probability dimensions, we can compute a matrix to be assigned to the provinces for prioritization
# The matrix should include high risk, high probability to low risk and low probability

# %%
#create a matrix with columns relative_risk and probability_rate for each province
train_copy.groupby('Province')[['relative_risk', 'Probability_rate']].mean()
# Out:
#              relative_risk  Probability_rate
# Province
# Albacete              0.00              0.00
# Alicante              0.00              0.00
# Almeria               0.00              0.00
# Avila                 0.31              0.06
# Barcelona             0.01              0.00
# Burgos                0.01              0.00
# Castellón             0.00              0.00
# Ciudad Real           0.01              0.00
# Cuenca                0.01              0.00
# Cádiz                 0.01              0.00
# Córdoba               0.00              0.00
# Girona                0.01              0.00
# Granada               0.01              0.00
# Guadalajara           0.01              0.00
# Huelva                0.02              0.00
# Huesca                0.02              0.00
# Jaén                  0.01              0.00
# La Coruña             0.00              0.00
# La Rioja              0.00              0.00
# León                  0.00              0.00
# Lleida                0.01              0.00
# Lugo                  0.01              0.00
# Madrid                0.06              0.00
# Málaga                0.01              0.00
# Orense                0.00              0.00
# Palencia              0.01              0.00
# Pontevedra            0.00              0.00
# Salamanca             0.00              0.00
# Segovia               0.00              0.00
# Sevilla               0.02              0.00
# Soria                 0.00              0.00
# Tarragona             0.01              0.00
# Teruel                0.00              0.00
# Toledo                0.01              0.00
# Valencia              0.01              0.00
# Valladolid            0.01              0.00
# Zamora                0.00              0.00
# Zaragoza              0.01              0.00

# %%
#create a matrix with columns relative_risk and probability_rate for each pipe material
train_copy.groupby('Material')[['relative_risk', 'Probability_rate']].mean()
# Out:
#           relative_risk  Probability_rate
# Material
# AO                 0.01              0.00
# CU                 0.09              0.01
# FD                 0.06              0.00
# FG                 0.20              0.01
# FI                 0.00              0.00
# FO                 0.00              0.00
# PA                 0.00              0.00
# PE                 0.01              0.00
# PN                 0.00              0.00
# PV                 0.00              0.00
# ZD                 0.04              0.01

# %%
train_copy.columns
# Out:
# Index(['PipeId', 'MaintenanceId', 'InspectionYear', 'InspectionDate',
#        'MonthsLastRev', 'Severity', 'Incidence', 'Province', 'Town',
#        'YearBuilt', 'Material', 'GasType', 'Diameter', 'Length', 'Pressure',
#        'NumConnections', 'NumConnectionsUnder', 'BoolBridle', 'No_Inspections',
#        'No_Incidences_Total', 'No_Previous_Incidences',
#        'average_severity_pipe', 'relative_risk', 'preventive_maintenance_rate',
#        'Probability_rate'],
#       dtype='object')

# %%
#creating a column with the Average of MonthsLastRev grouping per PipeId 
train_copy['Average_MonthsLastRev'] = train_copy.groupby('PipeId')['MonthsLastRev'].transform('mean')
cols = list(train_copy.columns.values)

train_copy.head(1)
# Out:
#    PipeId MaintenanceId  InspectionYear InspectionDate  MonthsLastRev  \
# 0  489616  ZRV-00003385            2013     2013-05-08             16
#
#    Severity  Incidence     Province                   Town  YearBuilt  \
# 0         4          0  Ciudad Real  Torralba de Calatrava    2012.00
#
#   Material      GasType  Diameter  Length  Pressure  NumConnections  \
# 0       PE  Gas natural        63    7.79      0.40               0
#
#    NumConnectionsUnder  BoolBridle  No_Inspections  No_Incidences_Total  \
# 0                    0       False               1                    0
#
#    No_Previous_Incidences  average_severity_pipe  relative_risk  \
# 0                    0.00                   4.00           0.00
#
#    preventive_maintenance_rate  Probability_rate  Average_MonthsLastRev
# 0                         0.00              0.00                  21.40

# %% [markdown]
# With this new column we know if the pipe is being inspected frequently or not taking as a thresold 24 months. We create a ne column that takes this threshold into consideration and creates a boolean

# %%
#create a new column named pipe_inspected_frequently with a value of 1 if pipe has an Average_MonthsLastRev of less or equal than 24
train_copy['pipe_inspected_frequently'] = np.where(train_copy['Average_MonthsLastRev'] <= 24, 1, 0)

#delete column Average_MonthsLastRev
train_copy.head(1)
# Out:
#    PipeId MaintenanceId  InspectionYear InspectionDate  MonthsLastRev  \
# 0  489616  ZRV-00003385            2013     2013-05-08             16
#
#    Severity  Incidence     Province                   Town  YearBuilt  \
# 0         4          0  Ciudad Real  Torralba de Calatrava    2012.00
#
#   Material      GasType  Diameter  Length  Pressure  NumConnections  \
# 0       PE  Gas natural        63    7.79      0.40               0
#
#    NumConnectionsUnder  BoolBridle  No_Inspections  No_Incidences_Total  \
# 0                    0       False               1                    0
#
#    No_Previous_Incidences  average_severity_pipe  relative_risk  \
# 0                    0.00                   4.00           0.00
#
#    preventive_maintenance_rate  Probability_rate  Average_MonthsLastRev  \
# 0                         0.00              0.00                  21.40
#
#    pipe_inspected_frequently
# 0                          1

# %%
train_copy.columns
# Out:
# Index(['PipeId', 'MaintenanceId', 'InspectionYear', 'InspectionDate',
#        'MonthsLastRev', 'Severity', 'Incidence', 'Province', 'Town',
#        'YearBuilt', 'Material', 'GasType', 'Diameter', 'Length', 'Pressure',
#        'NumConnections', 'NumConnectionsUnder', 'BoolBridle', 'No_Inspections',
#        'No_Incidences_Total', 'No_Previous_Incidences',
#        'average_severity_pipe', 'relative_risk', 'preventive_maintenance_rate',
#        'Probability_rate', 'Average_MonthsLastRev',
#        'pipe_inspected_frequently'],
#       dtype='object')

# %%
#creating a column named age_pipe_inspection with the difference between InspectionYear and YearBuilt and placing it in 10 th position
train_copy['Age_pipe_at_inspection'] = train_copy['InspectionYear'] - train_copy['YearBuilt']

#head of pipes with Age_pipe_at_inspection greater than 0
train_copy[train_copy['Age_pipe_at_inspection'] > 0].head(2)
# Out:
#    PipeId MaintenanceId  InspectionYear InspectionDate  MonthsLastRev  \
# 0  489616  ZRV-00003385            2013     2013-05-08             16
# 1  489616  ZRV-00003385            2015     2015-03-04             22
#
#    Severity  Incidence     Province                   Town  YearBuilt  \
# 0         4          0  Ciudad Real  Torralba de Calatrava    2012.00
# 1         4          0  Ciudad Real  Torralba de Calatrava    2012.00
#
#   Material      GasType  Diameter  Length  Pressure  NumConnections  \
# 0       PE  Gas natural        63    7.79      0.40               0
# 1       PE  Gas natural        63    7.79      0.40               0
#
#    NumConnectionsUnder  BoolBridle  No_Inspections  No_Incidences_Total  \
# 0                    0       False               1                    0
# 1                    0       False               2                    0
#
#    No_Previous_Incidences  average_severity_pipe  relative_risk  \
# 0                    0.00                   4.00           0.00
# 1                    0.00                   4.00           0.00
#
#    preventive_maintenance_rate  Probability_rate  Average_MonthsLastRev  \
# 0                         0.00              0.00                  21.40
# 1                         0.00              0.00                  21.40
#
#    pipe_inspected_frequently  Age_pipe_at_inspection
# 0                          1                    1.00
# 1                          1                    3.00

# %%
#describe Diameter on train_copy in mm
train_copy['Diameter'].describe()
# Out:
# count   6343899.00
# mean        119.51
# std          57.20
# min          10.00
# 25%          90.00
# 50%         110.00
# 75%         160.00
# max         609.00
# Name: Diameter, dtype: float64

# %%
train_copy['Length'].describe()
# Out:
# count   6343899.00
# mean         36.53
# std          72.15
# min           0.00
# 25%           4.00
# 50%          14.26
# 75%          44.60
# max       26100.94
# Name: Length, dtype: float64

# %%
#divide all values in Diameter by 1000 to convert to meters
train_copy['Diameter'] = train_copy['Diameter'] / 1000

# %%
#create a new variable called aspect that is equal to pressure divided by diameter multiplied by length
train_copy['aspect']=(train_copy['Pressure']/train_copy['Diameter'])*train_copy['Length']

# %%
#create a new column that divides the diameter by the pressure and name it Relative Thickness
train_copy['Relative_Thickness'] = train_copy['Diameter'] / train_copy['Pressure']

# %%
#creating a column named pipe_area that multiplies diameter by lenght by pi

train_copy['pipe_area'] = train_copy['Diameter'] * train_copy['Length'] * 3.1416

# %%
#Create a column called Total_Connections that adds NumConnections and NumConnectionsUnder
train_copy['Total_Connections'] = train_copy['NumConnections'] + train_copy['NumConnectionsUnder']

# %%
#create a column named area_connection that divides pipe_area by NumConnections
train_copy['area_connection'] = train_copy['Total_Connections']/ train_copy['pipe_area']

# %%
train_copy.head(2)
# Out:
#    PipeId MaintenanceId  InspectionYear InspectionDate  MonthsLastRev  \
# 0  489616  ZRV-00003385            2013     2013-05-08             16
# 1  489616  ZRV-00003385            2015     2015-03-04             22
#
#    Severity  Incidence     Province                   Town  YearBuilt  \
# 0         4          0  Ciudad Real  Torralba de Calatrava    2012.00
# 1         4          0  Ciudad Real  Torralba de Calatrava    2012.00
#
#   Material      GasType  Diameter  Length  Pressure  NumConnections  \
# 0       PE  Gas natural      0.06    7.79      0.40               0
# 1       PE  Gas natural      0.06    7.79      0.40               0
#
#    NumConnectionsUnder  BoolBridle  No_Inspections  No_Incidences_Total  \
# 0                    0       False               1                    0
# 1                    0       False               2                    0
#
#    No_Previous_Incidences  average_severity_pipe  relative_risk  \
# 0                    0.00                   4.00           0.00
# 1                    0.00                   4.00           0.00
#
#    preventive_maintenance_rate  Probability_rate  Average_MonthsLastRev  \
# 0                         0.00              0.00                  21.40
# 1                         0.00              0.00                  21.40
#
#    pipe_inspected_frequently  Age_pipe_at_inspection  aspect  \
# 0                          1                    1.00   49.47
# 1                          1                    3.00   49.47
#
#    Relative_Thickness  pipe_area  Total_Connections  area_connection
# 0                0.16       1.54                  0             0.00
# 1                0.16       1.54                  0             0.00

# %%
#create a column named incidence_area that divides incidence by pipe_area
train_copy['incidence_area'] = train_copy['No_Previous_Incidences'] / train_copy['pipe_area']

# %%
#create a boolean column named connection_bool that is 1 if NumConnections is greater than 1
train_copy['connection_bool'] = np.where(train_copy['NumConnections'] > 1, 1, 0)

# %%
#transform Inspection Date to datetime format
train_copy['InspectionDate'] = pd.to_datetime(train_copy['InspectionDate'])

# %%
train_copy.columns
# Out:
# Index(['PipeId', 'MaintenanceId', 'InspectionYear', 'InspectionDate',
#        'MonthsLastRev', 'Severity', 'Incidence', 'Province', 'Town',
#        'YearBuilt', 'Material', 'GasType', 'Diameter', 'Length', 'Pressure',
#        'NumConnections', 'NumConnectionsUnder', 'BoolBridle', 'No_Inspections',
#        'No_Incidences_Total', 'No_Previous_Incidences',
#        'average_severity_pipe', 'relative_risk', 'preventive_maintenance_rate',
#        'Probability_rate', 'Average_MonthsLastRev',
#        'pipe_inspected_frequently', 'Age_pipe_at_inspection', 'aspect',
#        'Relative_Thickness', 'pipe_area', 'Total_Connections',
#        'area_connection', 'incidence_area', 'connection_bool'],
#       dtype='object')

# %%
#hot encode severity_incidence column in the train_copy dataframe
train_copy = pd.get_dummies(train_copy, columns=['Severity'], prefix = ['Severity'])
train_copy.head(1)
# Out:
#    PipeId MaintenanceId  InspectionYear InspectionDate  MonthsLastRev  \
# 0  489616  ZRV-00003385            2013     2013-05-08             16
#
#    Incidence     Province                   Town  YearBuilt Material  \
# 0          0  Ciudad Real  Torralba de Calatrava    2012.00       PE
#
#        GasType  Diameter  Length  Pressure  NumConnections  \
# 0  Gas natural      0.06    7.79      0.40               0
#
#    NumConnectionsUnder  BoolBridle  No_Inspections  No_Incidences_Total  \
# 0                    0       False               1                    0
#
#    No_Previous_Incidences  average_severity_pipe  relative_risk  \
# 0                    0.00                   4.00           0.00
#
#    preventive_maintenance_rate  Probability_rate  Average_MonthsLastRev  \
# 0                         0.00              0.00                  21.40
#
#    pipe_inspected_frequently  Age_pipe_at_inspection  aspect  \
# 0                          1                    1.00   49.47
#
#    Relative_Thickness  pipe_area  Total_Connections  area_connection  \
# 0                0.16       1.54                  0             0.00
#
#    incidence_area  connection_bool  Severity_1  Severity_2  Severity_3  \
# 0            0.00                0           0           0           0
#
#    Severity_4
# 0           1

# %% [markdown]
# Mapping severity to stings before hot encoding

# %%
#change name of Severity_Incidence_1 column to Severity_low
train_copy = train_copy.rename(columns={'Severity_1': 'Severity_high'})
#change name of Severity_Incidence_2 column to Severity_medium
train_copy = train_copy.rename(columns={'Severity_2': 'Severity_medium'})
#change name of Severity_Incidence_3 column to Severity_high
train_copy = train_copy.rename(columns={'Severity_3': 'Severity_low'})
#drop Severity_4.0 column
train_copy = train_copy.drop(['Severity_4'], axis=1)

# %%
train_copy.head(1)
# Out:
#    PipeId MaintenanceId  InspectionYear InspectionDate  MonthsLastRev  \
# 0  489616  ZRV-00003385            2013     2013-05-08             16
#
#    Incidence     Province                   Town  YearBuilt Material  \
# 0          0  Ciudad Real  Torralba de Calatrava    2012.00       PE
#
#        GasType  Diameter  Length  Pressure  NumConnections  \
# 0  Gas natural      0.06    7.79      0.40               0
#
#    NumConnectionsUnder  BoolBridle  No_Inspections  No_Incidences_Total  \
# 0                    0       False               1                    0
#
#    No_Previous_Incidences  average_severity_pipe  relative_risk  \
# 0                    0.00                   4.00           0.00
#
#    preventive_maintenance_rate  Probability_rate  Average_MonthsLastRev  \
# 0                         0.00              0.00                  21.40
#
#    pipe_inspected_frequently  Age_pipe_at_inspection  aspect  \
# 0                          1                    1.00   49.47
#
#    Relative_Thickness  pipe_area  Total_Connections  area_connection  \
# 0                0.16       1.54                  0             0.00
#
#    incidence_area  connection_bool  Severity_high  Severity_medium  \
# 0            0.00                0              0                0
#
#    Severity_low
# 0             0

# %%
#for a row with same PipeId and InspectionYear, create a new column suming the number of Incidences per Pipe and name it No_Incidences
train_copy['No_Severity_Low'] = train_copy.groupby(['PipeId', 'InspectionYear'])['Severity_low'].transform('sum')
train_copy['No_Severity_Medium'] = train_copy.groupby(['PipeId', 'InspectionYear'])['Severity_medium'].transform('sum')
train_copy['No_Severity_High'] = train_copy.groupby(['PipeId', 'InspectionYear'])['Severity_high'].transform('sum')
#querying rows with different InspectionYear where Incidence is equal to 1
train_copy[(train_copy['InspectionYear'] != train_copy['YearBuilt']) & (train_copy['Severity_high'] == 1)].head(1)
# Out:
#           PipeId MaintenanceId  InspectionYear InspectionDate  MonthsLastRev  \
# 73247  188364471  ZRV-00002029            2013     2013-05-21             24
#
#        Incidence Province                  Town  YearBuilt Material  \
# 73247          1   Girona  Castell-Platja d'Aro    1997.00       PE
#
#            GasType  Diameter  Length  Pressure  NumConnections  \
# 73247  Gas natural      0.11   55.97      0.10               1
#
#        NumConnectionsUnder  BoolBridle  No_Inspections  No_Incidences_Total  \
# 73247                    0       False               2                    1
#
#        No_Previous_Incidences  average_severity_pipe  relative_risk  \
# 73247                    0.00                   3.40           0.00
#
#        preventive_maintenance_rate  Probability_rate  Average_MonthsLastRev  \
# 73247                         0.00              0.00                  24.20
#
#        pipe_inspected_frequently  Age_pipe_at_inspection  aspect  \
# 73247                          0                   16.00   50.88
#
#        Relative_Thickness  pipe_area  Total_Connections  area_connection  \
# 73247                1.10      19.34                  1             0.05
#
#        incidence_area  connection_bool  Severity_high  Severity_medium  \
# 73247            0.00                0              1                0
#
#        Severity_low  No_Severity_Low  No_Severity_Medium  No_Severity_High
# 73247             0                0                   0                 1

# %%
#for a same PipeId, create a new column No_Incidences_Total summing the previous value in No_Incidences starting in 2010
train_copy['No_Severity_Low_Total'] = train_copy.groupby(['PipeId'])['No_Severity_Low'].transform(lambda x: x.cumsum())
train_copy['No_Previous_Severity_Low']=train_copy['No_Severity_Low_Total']-train_copy['Severity_low']

train_copy['No_Severity_Medium_Total'] = train_copy.groupby(['PipeId'])['No_Severity_Medium'].transform(lambda x: x.cumsum())
train_copy['No_Previous_Severity_Medium']=train_copy['No_Severity_Medium_Total']-train_copy['Severity_medium']

train_copy['No_Severity_High_Total'] = train_copy.groupby(['PipeId'])['No_Severity_High'].transform(lambda x: x.cumsum())
train_copy['No_Previous_Severity_High']=train_copy['No_Severity_High_Total']-train_copy['Severity_high']

# %%
#querying rows with No_Incidences_Total > 1
train_copy[train_copy['No_Previous_Severity_High'] > 1].head(10)
# Out:
#             PipeId MaintenanceId  InspectionYear InspectionDate  \
# 405026   310152609  ZRV-00003479            2020     2020-06-05
# 787340   191115277  ZRV-00003674            2019     2019-01-16
# 2008444  133512092  ZRV-00004714            2018     2018-07-13
# 2008445  133512092  ZRV-00004714            2020     2020-07-10
# 2421638  292843631  ZRV-00003772            2020     2020-02-04
# 2779003  278440072  ZRV-00003719            2018     2018-10-29
# 2779004  278440072  ZRV-00003719            2020     2020-08-26
# 3689366  319364423  ZRV-00003992            2019     2019-04-09
# 4128449  307919622  ZRV-00003775            2016     2016-03-04
# 4128450  307919622  ZRV-00003775            2018     2018-01-18
#
#          MonthsLastRev  Incidence   Province                     Town  \
# 405026              24          0    Sevilla        Palomares del Río
# 787340              24          0  Barcelona                 Terrassa
# 2008444             24          0       León  San Andres del Rabanedo
# 2008445             24          0       León  San Andres del Rabanedo
# 2421638             22          1     Madrid                   Madrid
# 2779003             21          0     Madrid                   Madrid
# 2779004             22          0     Madrid                   Madrid
# 3689366             24          0    Almeria                    Ejido
# 4128449             22          0     Madrid                   Madrid
# 4128450             22          0     Madrid                   Madrid
#
#          YearBuilt Material      GasType  Diameter  Length  Pressure  \
# 405026     2007.00       PE  Gas natural      0.20  175.90      4.00
# 787340     1994.00       PE  Gas natural      0.06   58.72      4.00
# 2008444    2002.00       PE  Gas natural      0.20  206.66      4.00
# 2008445    2002.00       PE  Gas natural      0.20  206.66      4.00
# 2421638    1992.00       FD  Gas natural      0.25  122.41      0.03
# 2779003    1990.00       FD  Gas natural      0.20    6.47      0.03
# 2779004    1990.00       FD  Gas natural      0.20    6.47      0.03
# 3689366    2008.00       PE  Gas natural      0.04  144.67      4.00
# 4128449    1994.00       FD  Gas natural      0.15  109.71      0.03
# 4128450    1994.00       FD  Gas natural      0.15  109.71      0.03
#
#          NumConnections  NumConnectionsUnder  BoolBridle  No_Inspections  \
# 405026                8                    0       False               5
# 787340                9                    0       False               5
# 2008444              10                    0       False               4
# 2008445              10                    0       False               5
# 2421638              11                    0        True               6
# 2779003               0                    0        True               5
# 2779004               0                    0        True               6
# 3689366              14                    0       False               5
# 4128449               9                    0        True               4
# 4128450               9                    0        True               5
#
#          No_Incidences_Total  No_Previous_Incidences  average_severity_pipe  \
# 405026                     2                    2.00                   2.80
# 787340                     2                    2.00                   2.80
# 2008444                    2                    2.00                   2.80
# 2008445                    2                    2.00                   2.80
# 2421638                    4                    3.00                   2.67
# 2779003                    2                    2.00                   3.00
# 2779004                    2                    2.00                   3.00
# 3689366                    2                    2.00                   2.80
# 4128449                    2                    2.00                   3.00
# 4128450                    2                    2.00                   3.00
#
#          relative_risk  preventive_maintenance_rate  Probability_rate  \
# 405026            5.60                         1.12              0.40
# 787340            5.60                         1.12              0.40
# 2008444           5.60                         1.40              0.50
# 2008445           5.60                         1.12              0.40
# 2421638           8.00                         1.33              0.50
# 2779003           6.00                         1.20              0.40
# 2779004           6.00                         1.00              0.33
# 3689366           5.60                         1.12              0.40
# 4128449           6.00                         1.50              0.50
# 4128450           6.00                         1.20              0.40
#
#          Average_MonthsLastRev  pipe_inspected_frequently  \
# 405026                   24.00                          1
# 787340                   23.20                          1
# 2008444                  23.60                          1
# 2008445                  23.60                          1
# 2421638                  21.00                          1
# 2779003                  22.00                          1
# 2779004                  22.00                          1
# 3689366                  24.00                          1
# 4128449                  21.17                          1
# 4128450                  21.17                          1
#
#          Age_pipe_at_inspection   aspect  Relative_Thickness  pipe_area  \
# 405026                    13.00  3518.00                0.05     110.52
# 787340                    25.00  3728.25                0.02      11.62
# 2008444                   16.00  4133.24                0.05     129.85
# 2008445                   18.00  4133.24                0.05     129.85
# 2421638                   28.00    12.24               10.00      96.14
# 2779003                   28.00     0.81                8.00       4.06
# 2779004                   30.00     0.81                8.00       4.06
# 3689366                   11.00 14466.80                0.01      18.18
# 4128449                   22.00    18.29                6.00      51.70
# 4128450                   24.00    18.29                6.00      51.70
#
#          Total_Connections  area_connection  incidence_area  connection_bool  \
# 405026                   8             0.07            0.02                1
# 787340                   9             0.77            0.17                1
# 2008444                 10             0.08            0.02                1
# 2008445                 10             0.08            0.02                1
# 2421638                 11             0.11            0.03                1
# 2779003                  0             0.00            0.49                0
# 2779004                  0             0.00            0.49                0
# 3689366                 14             0.77            0.11                1
# 4128449                  9             0.17            0.04                1
# 4128450                  9             0.17            0.04                1
#
#          Severity_high  Severity_medium  Severity_low  No_Severity_Low  \
# 405026               0                0             0                0
# 787340               0                0             0                0
# 2008444              0                0             0                0
# 2008445              0                0             0                0
# 2421638              0                0             1                1
# 2779003              0                0             0                0
# 2779004              0                0             0                0
# 3689366              0                0             0                0
# 4128449              0                0             0                0
# 4128450              0                0             0                0
#
#          No_Severity_Medium  No_Severity_High  No_Severity_Low_Total  \
# 405026                    0                 0                      0
# 787340                    0                 0                      0
# 2008444                   0                 0                      0
# 2008445                   0                 0                      0
# 2421638                   0                 0                      2
# 2779003                   0                 0                      0
# 2779004                   0                 0                      0
# 3689366                   0                 0                      0
# 4128449                   0                 0                      0
# 4128450                   0                 0                      0
#
#          No_Previous_Severity_Low  No_Severity_Medium_Total  \
# 405026                          0                         0
# 787340                          0                         0
# 2008444                         0                         0
# 2008445                         0                         0
# 2421638                         1                         0
# 2779003                         0                         0
# 2779004                         0                         0
# 3689366                         0                         0
# 4128449                         0                         0
# 4128450                         0                         0
#
#          No_Previous_Severity_Medium  No_Severity_High_Total  \
# 405026                             0                       2
# 787340                             0                       2
# 2008444                            0                       2
# 2008445                            0                       2
# 2421638                            0                       2
# 2779003                            0                       2
# 2779004                            0                       2
# 3689366                            0                       2
# 4128449                            0                       2
# 4128450                            0                       2
#
#          No_Previous_Severity_High
# 405026                           2
# 787340                           2
# 2008444                          2
# 2008445                          2
# 2421638                          2
# 2779003                          2
# 2779004                          2
# 3689366                          2
# 4128449                          2
# 4128450                          2

# %% [markdown]
# Dropping more columns after feature engineering

# %%
#dropping columns that are not needed
train_copy = train_copy.drop(['No_Incidences_Total', 'No_Severity_Low','No_Severity_Medium','No_Severity_High','No_Severity_Low_Total', 'No_Severity_Medium_Total','No_Severity_High_Total'], axis=1)

# %%
#checking nulls
train_copy.isnull().sum()
# Out:
# PipeId                         0
# MaintenanceId                  0
# InspectionYear                 0
# InspectionDate                 0
# MonthsLastRev                  0
# Incidence                      0
# Province                       0
# Town                           0
# YearBuilt                      0
# Material                       0
# GasType                        0
# Diameter                       0
# Length                         0
# Pressure                       0
# NumConnections                 0
# NumConnectionsUnder            0
# BoolBridle                     0
# No_Inspections                 0
# No_Previous_Incidences         0
# average_severity_pipe          0
# relative_risk                  0
# preventive_maintenance_rate    0
# Probability_rate               0
# Average_MonthsLastRev          0
# pipe_inspected_frequently      0
# Age_pipe_at_inspection         0
# aspect                         0
# Relative_Thickness             0
# pipe_area                      0
# Total_Connections              0
# area_connection                7
# incidence_area                 7
# connection_bool                0
# Severity_high                  0
# Severity_medium                0
# Severity_low                   0
# No_Previous_Severity_Low       0
# No_Previous_Severity_Medium    0
# No_Previous_Severity_High      0
# dtype: int64

# %%
#delete nulls 
train_copy = train_copy.dropna()

# %%
train_copy['BoolBridle'].describe()
# Out:
# count     6343892
# unique          2
# top         False
# freq      5966504
# Name: BoolBridle, dtype: object

# %%
# Converting Boolbride into  boolean variable
def boolbridle(x):
    return 1 if x == 'True' else 0

# %%
# Apply function on dataset
train_copy['BoolBridle'] = train_copy['BoolBridle'].apply(lambda x: boolbridle(x))

# %%
#hot encode GasType column in the train_copy dataframe subset
train_copy = pd.get_dummies(train_copy, columns=['GasType'], prefix = ['GasType'])

# %%
#delete GasType_Gas propano column
train_copy = train_copy.drop(['GasType_Gas propano'], axis=1)

# %%
#change name of GasType_Gas natural column to gas_natural
train_copy = train_copy.rename(columns={'GasType_Gas natural': 'gas_natural'})
train_copy.head(1)
# Out:
#    PipeId MaintenanceId  InspectionYear InspectionDate  MonthsLastRev  \
# 0  489616  ZRV-00003385            2013     2013-05-08             16
#
#    Incidence     Province                   Town  YearBuilt Material  \
# 0          0  Ciudad Real  Torralba de Calatrava    2012.00       PE
#
#    Diameter  Length  Pressure  NumConnections  NumConnectionsUnder  \
# 0      0.06    7.79      0.40               0                    0
#
#    BoolBridle  No_Inspections  No_Previous_Incidences  average_severity_pipe  \
# 0           0               1                    0.00                   4.00
#
#    relative_risk  preventive_maintenance_rate  Probability_rate  \
# 0           0.00                         0.00              0.00
#
#    Average_MonthsLastRev  pipe_inspected_frequently  Age_pipe_at_inspection  \
# 0                  21.40                          1                    1.00
#
#    aspect  Relative_Thickness  pipe_area  Total_Connections  area_connection  \
# 0   49.47                0.16       1.54                  0             0.00
#
#    incidence_area  connection_bool  Severity_high  Severity_medium  \
# 0            0.00                0              0                0
#
#    Severity_low  No_Previous_Severity_Low  No_Previous_Severity_Medium  \
# 0             0                         0                            0
#
#    No_Previous_Severity_High  gas_natural
# 0                          0            1

# %%
#how much RAM is being used
import psutil
psutil.virtual_memory()
# Out:
# svmem(total=16861405184, available=5424074752, percent=67.8, used=11437330432, free=5424074752)

# %%
print (train_copy['Material'].unique())
# Out:
# ['PE' 'AO' 'PN' 'CU' 'FD' 'ZD' 'PV' 'PA' 'FI' 'FG' 'FO']

# %%
#Map df_combined Material column to the names of materials
train_copy['Material'] = train_copy['Material'].map({'PE': 'Polyethylene', 'AO': 'Acrylonitrile-Butadiene-Styrene', 'FD': 'Fiberglass-Reinforced Plastic', 
    'FG': 'Fiberglass', 'PN': 'Polypropylene', 'PA': 'Polyamide', 'FO': 'Flexible Polyolefin', 'FI': 'Flexible Polyvinyl Chloride', 'CU': 'Copper', 
    'PV': 'Polyvinylidene Fluoride', 'ZD': 'Zinc-Coated Steel', 'ZA': 'Zinc-Aluminum', 'CP': 'Cast Iron', 'CS': 'Cast Steel', 
    'ZC': 'Zinc-Coated Steel', 'ZM': 'Zinc-Magnesium','ZN': 'Zinc', 'AL': 'Aluminum', 'ZP': 'Zinc-Coated Steel', 'ZF': 'Zinc-Aluminum-Magnesium'})

# %%
#Hot enconde Material column in the train_copy dataframe subset
train_copy = pd.get_dummies(train_copy, columns=['Material'])
train_copy = train_copy.drop(['Material_Fiberglass', 'Material_Zinc-Coated Steel', 'Material_Polyvinylidene Fluoride','Material_Flexible Polyolefin', 'Material_Flexible Polyvinyl Chloride', 'Material_Polyamide'], axis=1)
train_copy.head(1)
# Out:
#    PipeId MaintenanceId  InspectionYear InspectionDate  MonthsLastRev  \
# 0  489616  ZRV-00003385            2013     2013-05-08             16
#
#    Incidence     Province                   Town  YearBuilt  Diameter  Length  \
# 0          0  Ciudad Real  Torralba de Calatrava    2012.00      0.06    7.79
#
#    Pressure  NumConnections  NumConnectionsUnder  BoolBridle  No_Inspections  \
# 0      0.40               0                    0           0               1
#
#    No_Previous_Incidences  average_severity_pipe  relative_risk  \
# 0                    0.00                   4.00           0.00
#
#    preventive_maintenance_rate  Probability_rate  Average_MonthsLastRev  \
# 0                         0.00              0.00                  21.40
#
#    pipe_inspected_frequently  Age_pipe_at_inspection  aspect  \
# 0                          1                    1.00   49.47
#
#    Relative_Thickness  pipe_area  Total_Connections  area_connection  \
# 0                0.16       1.54                  0             0.00
#
#    incidence_area  connection_bool  Severity_high  Severity_medium  \
# 0            0.00                0              0                0
#
#    Severity_low  No_Previous_Severity_Low  No_Previous_Severity_Medium  \
# 0             0                         0                            0
#
#    No_Previous_Severity_High  gas_natural  \
# 0                          0            1
#
#    Material_Acrylonitrile-Butadiene-Styrene  Material_Copper  \
# 0                                         0                0
#
#    Material_Fiberglass-Reinforced Plastic  Material_Polyethylene  \
# 0                                       0                      1
#
#    Material_Polypropylene
# 0                       0

# %% [markdown]
# Creating polynomials

# %%
#create polinomial features in train_copy for Diameter, Length, Pressure
poly = PolynomialFeatures(2)
train_copy['Diameter2'] = poly.fit_transform(train_copy[['Diameter']])[:,2]
train_copy['Length2'] = poly.fit_transform(train_copy[['Length']])[:,2]
train_copy['Pressure2'] = poly.fit_transform(train_copy[['Pressure']])[:,2]
train_copy.head(1)
# Out:
#    PipeId MaintenanceId  InspectionYear InspectionDate  MonthsLastRev  \
# 0  489616  ZRV-00003385            2013     2013-05-08             16
#
#    Incidence     Province                   Town  YearBuilt  Diameter  Length  \
# 0          0  Ciudad Real  Torralba de Calatrava    2012.00      0.06    7.79
#
#    Pressure  NumConnections  NumConnectionsUnder  BoolBridle  No_Inspections  \
# 0      0.40               0                    0           0               1
#
#    No_Previous_Incidences  average_severity_pipe  relative_risk  \
# 0                    0.00                   4.00           0.00
#
#    preventive_maintenance_rate  Probability_rate  Average_MonthsLastRev  \
# 0                         0.00              0.00                  21.40
#
#    pipe_inspected_frequently  Age_pipe_at_inspection  aspect  \
# 0                          1                    1.00   49.47
#
#    Relative_Thickness  pipe_area  Total_Connections  area_connection  \
# 0                0.16       1.54                  0             0.00
#
#    incidence_area  connection_bool  Severity_high  Severity_medium  \
# 0            0.00                0              0                0
#
#    Severity_low  No_Previous_Severity_Low  No_Previous_Severity_Medium  \
# 0             0                         0                            0
#
#    No_Previous_Severity_High  gas_natural  \
# 0                          0            1
#
#    Material_Acrylonitrile-Butadiene-Styrene  Material_Copper  \
# 0                                         0                0
#
#    Material_Fiberglass-Reinforced Plastic  Material_Polyethylene  \
# 0                                       0                      1
#
#    Material_Polypropylene  Diameter2  Length2  Pressure2
# 0                       0       0.00    60.72       0.16

# %%
train_copy.shape
# Out:
# (6343892, 46)

# %%
# free up memory
del df_sample

# %% [markdown]
# <a id='5'></a>
# # <font color=green> 5. Adding a new dataset </font>

# %% [markdown]
# We want to extract value of two categorical variables, Town and Province but the way we have them now they are useless.
#
# We will add two new datasets, one with weather climate features and another with denisty of population

# %%
#point to the folder where the data is stored
os.chdir(r"C:\Users\pedro\datathon\base\complementary_datasets")

# Loading provincias dataset
provincias = pd.read_excel('promedio_tiempo_provincia_anual.xlsx')

# %%
normalize_characters(train_copy, 'Province')
normalize_characters(provincias, 'Province')
# Out:
#    PipeId MaintenanceId  InspectionYear InspectionDate  MonthsLastRev  \
# 0  489616  ZRV-00003385            2013     2013-05-08             16
# 1  489616  ZRV-00003385            2015     2015-03-04             22
#
#    Incidence     Province                   Town  YearBuilt  Diameter  Length  \
# 0          0  ciudad real  Torralba de Calatrava    2012.00      0.06    7.79
# 1          0  ciudad real  Torralba de Calatrava    2012.00      0.06    7.79
#
#    Pressure  NumConnections  NumConnectionsUnder  BoolBridle  No_Inspections  \
# 0      0.40               0                    0           0               1
# 1      0.40               0                    0           0               2
#
#    No_Previous_Incidences  average_severity_pipe  relative_risk  \
# 0                    0.00                   4.00           0.00
# 1                    0.00                   4.00           0.00
#
#    preventive_maintenance_rate  Probability_rate  Average_MonthsLastRev  \
# 0                         0.00              0.00                  21.40
# 1                         0.00              0.00                  21.40
#
#    pipe_inspected_frequently  Age_pipe_at_inspection  aspect  \
# 0                          1                    1.00   49.47
# 1                          1                    3.00   49.47
#
#    Relative_Thickness  pipe_area  Total_Connections  area_connection  \
# 0                0.16       1.54                  0             0.00
# 1                0.16       1.54                  0             0.00
#
#    incidence_area  connection_bool  Severity_high  Severity_medium  \
# 0            0.00                0              0                0
# 1            0.00                0              0                0
#
#    Severity_low  No_Previous_Severity_Low  No_Previous_Severity_Medium  \
# 0             0                         0                            0
# 1             0                         0                            0
#
#    No_Previous_Severity_High  gas_natural  \
# 0                          0            1
# 1                          0            1
#
#    Material_Acrylonitrile-Butadiene-Styrene  Material_Copper  \
# 0                                         0                0
# 1                                         0                0
#
#    Material_Fiberglass-Reinforced Plastic  Material_Polyethylene  \
# 0                                       0                      1
# 1                                       0                      1
#
#    Material_Polypropylene  Diameter2  Length2  Pressure2
# 0                       0       0.00    60.72       0.16
# 1                       0       0.00    60.72       0.16
#    Province  Average yearly temperature (°C)  Min. Temperature (°C)  \
# 0    lleida                            15.46                   1.80
# 1  la rioja                            12.38                   1.70
#
#    Max. Temperature (°C)  Yearly Rainfall (mm)  Average year Humidity (%)  \
# 0                  32.90                   461                       0.59
# 1                  26.90                   633                       0.72
#
#    Rainy days per year (days)  Yearly Sun Hours (hours)
# 0                          50                    112.40
# 1                          87                     85.20

# %%
#join train_copy and provincias on Province
train_copy = train_copy.merge(provincias, on='Province', how='left')

# %%
del provincias

# %%
train_copy.head(2)
# Out:
#    PipeId MaintenanceId  InspectionYear InspectionDate  MonthsLastRev  \
# 0  489616  ZRV-00003385            2013     2013-05-08             16
# 1  489616  ZRV-00003385            2015     2015-03-04             22
#
#    Incidence     Province                   Town  YearBuilt  Diameter  Length  \
# 0          0  ciudad real  Torralba de Calatrava    2012.00      0.06    7.79
# 1          0  ciudad real  Torralba de Calatrava    2012.00      0.06    7.79
#
#    Pressure  NumConnections  NumConnectionsUnder  BoolBridle  No_Inspections  \
# 0      0.40               0                    0           0               1
# 1      0.40               0                    0           0               2
#
#    No_Previous_Incidences  average_severity_pipe  relative_risk  \
# 0                    0.00                   4.00           0.00
# 1                    0.00                   4.00           0.00
#
#    preventive_maintenance_rate  Probability_rate  Average_MonthsLastRev  \
# 0                         0.00              0.00                  21.40
# 1                         0.00              0.00                  21.40
#
#    pipe_inspected_frequently  Age_pipe_at_inspection  aspect  \
# 0                          1                    1.00   49.47
# 1                          1                    3.00   49.47
#
#    Relative_Thickness  pipe_area  Total_Connections  area_connection  \
# 0                0.16       1.54                  0             0.00
# 1                0.16       1.54                  0             0.00
#
#    incidence_area  connection_bool  Severity_high  Severity_medium  \
# 0            0.00                0              0                0
# 1            0.00                0              0                0
#
#    Severity_low  No_Previous_Severity_Low  No_Previous_Severity_Medium  \
# 0             0                         0                            0
# 1             0                         0                            0
#
#    No_Previous_Severity_High  gas_natural  \
# 0                          0            1
# 1                          0            1
#
#    Material_Acrylonitrile-Butadiene-Styrene  Material_Copper  \
# 0                                         0                0
# 1                                         0                0
#
#    Material_Fiberglass-Reinforced Plastic  Material_Polyethylene  \
# 0                                       0                      1
# 1                                       0                      1
#
#    Material_Polypropylene  Diameter2  Length2  Pressure2  \
# 0                       0       0.00    60.72       0.16
# 1                       0       0.00    60.72       0.16
#
#    Average yearly temperature (°C)  Min. Temperature (°C)  \
# 0                            15.44                   1.50
# 1                            15.44                   1.50
#
#    Max. Temperature (°C)  Yearly Rainfall (mm)  Average year Humidity (%)  \
# 0                  33.70                   438                       0.55
# 1                  33.70                   438                       0.55
#
#    Rainy days per year (days)  Yearly Sun Hours (hours)
# 0                          52                    107.50
# 1                          52                    107.50

# %%
#point to the folder where the data is stored for Pedro
os.chdir(r"C:\Users\pedro\datathon\base\complementary_datasets")

df_population = pd.read_excel('population_density_province.xlsx')

# %%
normalize_characters(train_copy, 'Province')
normalize_characters(df_population, 'Province')
# Out:
#    PipeId MaintenanceId  InspectionYear InspectionDate  MonthsLastRev  \
# 0  489616  ZRV-00003385            2013     2013-05-08             16
# 1  489616  ZRV-00003385            2015     2015-03-04             22
#
#    Incidence     Province                   Town  YearBuilt  Diameter  Length  \
# 0          0  ciudad real  Torralba de Calatrava    2012.00      0.06    7.79
# 1          0  ciudad real  Torralba de Calatrava    2012.00      0.06    7.79
#
#    Pressure  NumConnections  NumConnectionsUnder  BoolBridle  No_Inspections  \
# 0      0.40               0                    0           0               1
# 1      0.40               0                    0           0               2
#
#    No_Previous_Incidences  average_severity_pipe  relative_risk  \
# 0                    0.00                   4.00           0.00
# 1                    0.00                   4.00           0.00
#
#    preventive_maintenance_rate  Probability_rate  Average_MonthsLastRev  \
# 0                         0.00              0.00                  21.40
# 1                         0.00              0.00                  21.40
#
#    pipe_inspected_frequently  Age_pipe_at_inspection  aspect  \
# 0                          1                    1.00   49.47
# 1                          1                    3.00   49.47
#
#    Relative_Thickness  pipe_area  Total_Connections  area_connection  \
# 0                0.16       1.54                  0             0.00
# 1                0.16       1.54                  0             0.00
#
#    incidence_area  connection_bool  Severity_high  Severity_medium  \
# 0            0.00                0              0                0
# 1            0.00                0              0                0
#
#    Severity_low  No_Previous_Severity_Low  No_Previous_Severity_Medium  \
# 0             0                         0                            0
# 1             0                         0                            0
#
#    No_Previous_Severity_High  gas_natural  \
# 0                          0            1
# 1                          0            1
#
#    Material_Acrylonitrile-Butadiene-Styrene  Material_Copper  \
# 0                                         0                0
# 1                                         0                0
#
#    Material_Fiberglass-Reinforced Plastic  Material_Polyethylene  \
# 0                                       0                      1
# 1                                       0                      1
#
#    Material_Polypropylene  Diameter2  Length2  Pressure2  \
# 0                       0       0.00    60.72       0.16
# 1                       0       0.00    60.72       0.16
#
#    Average yearly temperature (°C)  Min. Temperature (°C)  \
# 0                            15.44                   1.50
# 1                            15.44                   1.50
#
#    Max. Temperature (°C)  Yearly Rainfall (mm)  Average year Humidity (%)  \
# 0                  33.70                   438                       0.55
# 1                  33.70                   438                       0.55
#
#    Rainy days per year (days)  Yearly Sun Hours (hours)
# 0                          52                    107.50
# 1                          52                    107.50
#    Province  Area (sq km)  InspectionYear  Population  \
# 0  albacete         14926            2022      385727
# 1  albacete         14926            2021      386464
#
#    Population density (persons/sqkm)
# 0                              25.84
# 1                              25.89

# %%
#merge train_copy with df_population based on Province and InspectionYear and just for the provinces which exist in train_copy df
train_copy = pd.merge(train_copy, df_population, on=['Province', 'InspectionYear'], how='left')

# %%
#point to the folder where the data is stored
os.chdir(r"C:\Users\alfon\Desktop\Máster IE - Business Analytics & Big Data\3rd Term\Sustainability Datathon\Data\Data cleaned")
#export the dataframe to a csv file
train_copy.to_csv('train_consolidated_with_outliers_and_pop.csv', index=False)

# %% [markdown]
# <a id='6'></a>
# # <font color=green> 6. Outliers </font>

# %%
#delete outliers in Year_Built column < 1960
train_copy = train_copy[train_copy['YearBuilt'] > 1975]

# %%
#Show the distribution of YearBuilt
plt.figure(figsize=(10,5))
sns.distplot(train_copy['YearBuilt'], color='blue', bins=100, hist_kws={'alpha': 0.4});
plt.show()
# Out:
# <AxesSubplot:xlabel='YearBuilt', ylabel='Density'>

# %%
#eliminate values higher than 40 in MonthsLastRev column
train_copy = train_copy[train_copy['MonthsLastRev'] < 40]

# %%
#show the distribution of MonthsLastRev
plt.figure(figsize=(10,5))
sns.distplot(train_copy['MonthsLastRev'], color='blue', bins=100, hist_kws={'alpha': 0.4});
plt.show()
# Out:
# <AxesSubplot:xlabel='MonthsLastRev', ylabel='Density'>

# %%
# use describe function of monthslastrev column to see the distribution of values
train_copy['MonthsLastRev'].describe()
# Out:
# count   6063082.00
# mean         22.97
# std           3.10
# min           0.00
# 25%          23.00
# 50%          24.00
# 75%          24.00
# max          39.00
# Name: MonthsLastRev, dtype: float64

# %%
#eliminate values higher than 400 in diameter column
train_copy = train_copy[train_copy['Diameter'] < 400]

# %%
#show the distribution of Diameter
plt.figure(figsize=(10,5))
sns.distplot(train_copy['Diameter'], color='blue', bins=100, hist_kws={'alpha': 0.4});
plt.show()
# Out:
# <AxesSubplot:xlabel='Diameter', ylabel='Density'>

# %%
train_copy.shape
# Out:
# (6063082, 56)

# %%
#graph histogram of MonthsLastRev column
train_copy['MonthsLastRev'].hist()
# Out:
# <AxesSubplot:>

# %%
#plot column Length
train_copy['Length'].value_counts()
# Out:
# 2.00      26494
# 1.00      25303
# 0.50      18397
# 1.00      18205
# 1.50      17951
#           ...
# 72.62         1
# 221.67        1
# 335.60        1
# 327.32        1
# 243.87        1
# Name: Length, Length: 204058, dtype: int64

# %%
#plot histogram of Length column
train_copy['Length'].hist()
# Out:
# <AxesSubplot:>

# %%
train_copy.columns
# Out:
# Index(['PipeId', 'MaintenanceId', 'InspectionYear', 'InspectionDate',
#        'MonthsLastRev', 'Incidence', 'Province', 'Town', 'YearBuilt',
#        'Diameter', 'Length', 'Pressure', 'NumConnections',
#        'NumConnectionsUnder', 'BoolBridle', 'No_Inspections',
#        'No_Previous_Incidences', 'average_severity_pipe', 'relative_risk',
#        'preventive_maintenance_rate', 'Probability_rate',
#        'Average_MonthsLastRev', 'pipe_inspected_frequently',
#        'Age_pipe_at_inspection', 'aspect', 'Relative_Thickness', 'pipe_area',
#        'Total_Connections', 'area_connection', 'incidence_area',
#        'connection_bool', 'Severity_high', 'Severity_medium', 'Severity_low',
#        'No_Previous_Severity_Low', 'No_Previous_Severity_Medium',
#        'No_Previous_Severity_High', 'gas_natural',
#        'Material_Acrylonitrile-Butadiene-Styrene', 'Material_Copper',
#        'Material_Fiberglass-Reinforced Plastic', 'Material_Polyethylene',
#        'Material_Polypropylene', 'Diameter2', 'Length2', 'Pressure2',
#        'Average yearly temperature (°C)', 'Min. Temperature (°C)',
#        'Max. Temperature (°C)', 'Yearly Rainfall (mm)',
#        'Average year Humidity (%)', 'Rainy days per year (days)',
#        'Yearly Sun Hours (hours)', 'Area (sq km)', 'Population',
#        'Population density (persons/sqkm)'],
#       dtype='object')

# %% [markdown]
# <a id='7'></a>
# # <font color=green> 7. Dropping </font>

# %%
#delete the rows with YearBuilt higher than InspectionYear
train_copy = train_copy.drop(train_copy[(train_copy['YearBuilt'] > train_copy['InspectionYear'])].index)

# %% [markdown]
# <a id='8'></a>
# # <font color=green> 8. Exporting resulting dataframe for next notebook</font>

# %%
#point to the folder where the data is stored
os.chdir(r"C:\Users\pedro\datathon")
#export the dataframe to a csv file
train_copy.to_csv('train_consolidated.csv', index=False)
# Out:
#   Cell In[9], line 2
#     os.chdir(r"C:\Users\pedro\datathon
#              ^
# SyntaxError: unterminated string literal (detected at line 2)

# %% [markdown]
# <a id='9'></a>
# # <font color=green> 9. Pandas Profiling Report</font>

# %%
#pandas profiling on the train_copy dataframe
profile = ProfileReport(train_copy, title='Pandas Profiling Report', html={'style':{'full_width':True}})
profile
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 2
#       1 #pandas profiling on the train_copy dataframe
# ----> 2 profile = ProfileReport(train_copy, title='Pandas Profiling Report', html={'style':{'full_width':True}})
#       3 profile
#
# NameError: name 'train_copy' is not defined

# %% [markdown]
# ### ==========================================================================
# ## End of Notebook 3: Data Wrangling and Feature Engineering (3/6)
# ### ==========================================================================
